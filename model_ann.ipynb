# %% [markdown]
# # Artificial Neural Network

# %% [markdown]
# ### Setup

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np
import matplotlib.pyplot as plt
from utils_io import load_step, save_step
from sklearn.model_selection import GridSearchCV, KFold, RandomizedSearchCV
from scipy.stats import randint, loguniform

# %%
y_train = load_step("y_train")
y_test = load_step("y_test")
X_train_scaled = load_step("X_train_scaled")
X_test_scaled = load_step("X_test_scaled")

# %% [markdown]
# ### Initialize Model

# %%
# Make sure y is 1D (your existing code)
y_train_arr = np.ravel(y_train)

# Base ANN (only keep things FIXED that we do NOT tune)
ann_base = MLPRegressor(
    hidden_layer_sizes=(64, 32),   # will be overwritten by search
    activation="relu",             # will be overwritten by search
    solver="adam",                 # keep fixed: good default for large data
    alpha=1e-3,                    # will be overwritten by search
    learning_rate="adaptive",      # will be overwritten by search
    learning_rate_init=1e-3,       # will be overwritten by search
    max_iter=1000,
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=10,
    random_state=42
)

# %% [markdown]
# ### Hyperparameter Optimization

# %%
# --- RANDOM SEARCH SPACE ---

param_distributions = {
    # network depth & width (capacity)
    "hidden_layer_sizes": [
        (32,), (64,), (128,),           # shallow, single layer
        (64, 32), (128, 64),            # like your current + bigger
        (128, 64, 32), (256, 128, 64)   # deeper & wider (aggressive)
    ],
    
    # activation: how nonlinear the network can be
    "activation": ["relu", "tanh"],
    
    # L2 regularization: controls overfitting of weights
    # loguniform -> each order of magnitude equally likely
    "alpha": loguniform(1e-5, 1e1),   # 10⁻⁶ … 10⁻¹
    
    # initial learning rate for Adam
    "learning_rate_init": loguniform(1e-4, 1e-1),  # 10⁻⁴ … 10⁻¹
    
    # learning rate schedule: stable vs. more flexible
    "learning_rate": ["constant", "adaptive"],
    
    # batch size: influences noise in gradient & speed
    "batch_size": [64, 128, 256, 512]
}

# CV like in your other models
cv = KFold(n_splits=5, shuffle=True, random_state=42)

ann_random_search = RandomizedSearchCV(
    estimator=ann_base,
    param_distributions=param_distributions,
    n_iter=50,  # can increase to 100 if you have time/compute
    scoring="neg_mean_squared_error",
    cv=cv,
    n_jobs=-1,
    random_state=42,
    verbose=2
)

print("Running Random Search for ANN (MLPRegressor)...")
ann_random_search.fit(X_train_scaled, y_train_arr)

print("\nBest parameters (ANN):")
print(ann_random_search.best_params_)
print(f"Best CV MSE (negative): {ann_random_search.best_score_:.4f}")
# Out:
# Running Random Search for ANN (MLPRegressor)...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END activation=relu, alpha=0.004731474644815001, batch_size=256, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.0396760507705299; total time=   3.5s
# [CV] END activation=relu, alpha=0.004731474644815001, batch_size=256, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.0396760507705299; total time=   4.8s
# [CV] END activation=relu, alpha=0.004731474644815001, batch_size=256, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.0396760507705299; total time=   5.6s
# [CV] END activation=relu, alpha=0.004731474644815001, batch_size=256, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.0396760507705299; total time=   7.2s
# [CV] END activation=tanh, alpha=7.19781876906885e-05, batch_size=256, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.0812324508558869; total time=   4.2s
# [CV] END activation=relu, alpha=0.601530871839645, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.006251373574521752; total time=   7.8s
# [CV] END activation=relu, alpha=0.601530871839645, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.006251373574521752; total time=   7.9s
# [CV] END activation=relu, alpha=0.004731474644815001, batch_size=256, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.0396760507705299; total time=   8.1s
# [CV] END activation=tanh, alpha=7.19781876906885e-05, batch_size=256, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.0812324508558869; total time=   3.1s
# [CV] END activation=relu, alpha=0.601530871839645, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.006251373574521752; total time=   8.5s
# [CV] END activation=relu, alpha=0.601530871839645, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.006251373574521752; total time=   8.7s
# [CV] END activation=relu, alpha=0.601530871839645, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.006251373574521752; total time=   9.0s
# [CV] END activation=tanh, alpha=7.19781876906885e-05, batch_size=256, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.0812324508558869; total time=   3.4s
# [CV] END activation=tanh, alpha=7.19781876906885e-05, batch_size=256, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.0812324508558869; total time=   3.8s
# [CV] END activation=tanh, alpha=7.19781876906885e-05, batch_size=256, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.0812324508558869; total time=   3.5s
# [CV] END activation=tanh, alpha=4.278743516759817, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.007119418600172993; total time=   5.9s
# [CV] END activation=tanh, alpha=4.278743516759817, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.007119418600172993; total time=   7.3s
# [CV] END activation=tanh, alpha=4.278743516759817, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.007119418600172993; total time=   8.5s
# [CV] END activation=tanh, alpha=0.014077923139972392, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0037525283395739802; total time=   8.1s
# [CV] END activation=tanh, alpha=4.278743516759817, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.007119418600172993; total time=   8.8s
# [CV] END activation=tanh, alpha=4.278743516759817, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.007119418600172993; total time=   9.4s
# [CV] END activation=tanh, alpha=0.014077923139972392, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0037525283395739802; total time=   8.8s
# [CV] END activation=tanh, alpha=0.5141096648805742, batch_size=256, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.08906204386161683; total time=   1.7s
# [CV] END activation=tanh, alpha=0.5141096648805742, batch_size=256, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.08906204386161683; total time=   1.6s
# [CV] END activation=tanh, alpha=0.014077923139972392, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0037525283395739802; total time=  10.7s
# [CV] END activation=tanh, alpha=0.014077923139972392, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0037525283395739802; total time=   8.7s
# [CV] END activation=tanh, alpha=0.014077923139972392, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0037525283395739802; total time=   9.8s
# [CV] END activation=tanh, alpha=0.5141096648805742, batch_size=256, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.08906204386161683; total time=   2.6s
# [CV] END activation=tanh, alpha=0.5141096648805742, batch_size=256, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.08906204386161683; total time=   3.6s
# [CV] END activation=tanh, alpha=0.5141096648805742, batch_size=256, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.08906204386161683; total time=   3.9s
# [CV] END activation=relu, alpha=6.870101665590028e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0004992453416923984; total time=  12.8s
# [CV] END activation=tanh, alpha=4.9352962094020985, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.0014330109455635695; total time=   7.1s
# [CV] END activation=relu, alpha=6.870101665590028e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0004992453416923984; total time=  17.9s
# [CV] END activation=relu, alpha=1.8997763474111268e-05, batch_size=256, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.0022464551680532615; total time=  18.3s
# [CV] END activation=relu, alpha=1.8997763474111268e-05, batch_size=256, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.0022464551680532615; total time=  18.1s
# [CV] END activation=tanh, alpha=4.9352962094020985, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.0014330109455635695; total time=   6.8s
# [CV] END activation=tanh, alpha=4.9352962094020985, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.0014330109455635695; total time=   6.6s
# [CV] END activation=tanh, alpha=3.855073690026178e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.011214774784159465; total time=   2.1s
# [CV] END activation=relu, alpha=6.870101665590028e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0004992453416923984; total time=  28.1s
# [CV] END activation=relu, alpha=1.8997763474111268e-05, batch_size=256, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.0022464551680532615; total time=  20.4s
# [CV] END activation=relu, alpha=1.8997763474111268e-05, batch_size=256, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.0022464551680532615; total time=  23.0s
# [CV] END activation=tanh, alpha=4.9352962094020985, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.0014330109455635695; total time=   6.4s
# [CV] END activation=tanh, alpha=3.855073690026178e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.011214774784159465; total time=   1.7s
# [CV] END activation=tanh, alpha=3.855073690026178e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.011214774784159465; total time=   1.8s
# [CV] END activation=relu, alpha=6.870101665590028e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0004992453416923984; total time=  28.8s
# [CV] END activation=relu, alpha=1.8997763474111268e-05, batch_size=256, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.0022464551680532615; total time=  22.1s
# [CV] END activation=tanh, alpha=4.9352962094020985, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.0014330109455635695; total time=   6.1s
# [CV] END activation=relu, alpha=6.870101665590028e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0004992453416923984; total time=  29.4s
# [CV] END activation=tanh, alpha=3.855073690026178e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.011214774784159465; total time=   6.6s
# [CV] END activation=tanh, alpha=0.0944351568796267, batch_size=128, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.0004205571187007212; total time=   9.3s
# [CV] END activation=tanh, alpha=0.0944351568796267, batch_size=128, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.0004205571187007212; total time=   9.9s
# [CV] END activation=tanh, alpha=3.855073690026178e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=constant, learning_rate_init=0.011214774784159465; total time=  13.1s
# [CV] END activation=tanh, alpha=0.0944351568796267, batch_size=128, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.0004205571187007212; total time=  10.3s
# [CV] END activation=tanh, alpha=0.0944351568796267, batch_size=128, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.0004205571187007212; total time=  10.5s
# [CV] END activation=tanh, alpha=0.0944351568796267, batch_size=128, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.0004205571187007212; total time=   6.8s
# [CV] END activation=tanh, alpha=0.009355380606452175, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.0014899847475658245; total time=  21.4s
# [CV] END activation=tanh, alpha=0.009355380606452175, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.0014899847475658245; total time=  21.1s
# [CV] END activation=tanh, alpha=0.0001285661779146793, batch_size=256, hidden_layer_sizes=(64,), learning_rate=adaptive, learning_rate_init=0.0022349221517675532; total time=  10.0s
# [CV] END activation=tanh, alpha=0.009355380606452175, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.0014899847475658245; total time=  23.5s
# [CV] END activation=tanh, alpha=0.0001285661779146793, batch_size=256, hidden_layer_sizes=(64,), learning_rate=adaptive, learning_rate_init=0.0022349221517675532; total time=  10.5s
# [CV] END activation=tanh, alpha=0.0001285661779146793, batch_size=256, hidden_layer_sizes=(64,), learning_rate=adaptive, learning_rate_init=0.0022349221517675532; total time=  13.8s
# [CV] END activation=tanh, alpha=0.0001285661779146793, batch_size=256, hidden_layer_sizes=(64,), learning_rate=adaptive, learning_rate_init=0.0022349221517675532; total time=  16.5s
# [CV] END activation=tanh, alpha=0.0001285661779146793, batch_size=256, hidden_layer_sizes=(64,), learning_rate=adaptive, learning_rate_init=0.0022349221517675532; total time=  12.5s
# [CV] END activation=tanh, alpha=0.009355380606452175, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.0014899847475658245; total time=  29.9s
# [CV] END activation=tanh, alpha=0.009355380606452175, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.0014899847475658245; total time=  32.6s
# [CV] END activation=tanh, alpha=0.0001499329805509155, batch_size=64, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.03416658290996044; total time=   9.1s
# [CV] END activation=tanh, alpha=0.0001499329805509155, batch_size=64, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.03416658290996044; total time=   8.6s
# [CV] END activation=tanh, alpha=0.0001499329805509155, batch_size=64, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.03416658290996044; total time=   9.1s
# [CV] END activation=tanh, alpha=0.0001499329805509155, batch_size=64, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.03416658290996044; total time=   9.9s
# [CV] END activation=tanh, alpha=0.0001499329805509155, batch_size=64, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.03416658290996044; total time=   8.7s
# [CV] END activation=tanh, alpha=2.3386439256208704, batch_size=128, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.0009541624171184558; total time=  30.6s
# [CV] END activation=tanh, alpha=2.3386439256208704, batch_size=128, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.0009541624171184558; total time=  34.4s
# [CV] END activation=tanh, alpha=2.3386439256208704, batch_size=128, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.0009541624171184558; total time=  34.3s
# [CV] END activation=relu, alpha=0.0004247116662617141, batch_size=64, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.0006963114377829289; total time=  19.1s
# [CV] END activation=tanh, alpha=2.3386439256208704, batch_size=128, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.0009541624171184558; total time=  43.7s
# [CV] END activation=relu, alpha=0.0004247116662617141, batch_size=64, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.0006963114377829289; total time=  24.2s
# [CV] END activation=tanh, alpha=2.3386439256208704, batch_size=128, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.0009541624171184558; total time=  47.8s
# [CV] END activation=relu, alpha=0.0004247116662617141, batch_size=64, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.0006963114377829289; total time=  38.0s
# [CV] END activation=relu, alpha=0.0004247116662617141, batch_size=64, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.0006963114377829289; total time=  34.4s
# [CV] END activation=relu, alpha=0.0004247116662617141, batch_size=64, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.0006963114377829289; total time=  41.0s
# [CV] END activation=relu, alpha=0.003470634537133488, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.00010388823104027947; total time=  49.9s
# [CV] END activation=relu, alpha=0.00015597479536983742, batch_size=512, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.020597335357437203; total time=   6.6s
# [CV] END activation=relu, alpha=0.00015597479536983742, batch_size=512, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.020597335357437203; total time=   5.5s
# [CV] END activation=relu, alpha=0.003470634537133488, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.00010388823104027947; total time=  55.5s
# [CV] END activation=relu, alpha=0.003470634537133488, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.00010388823104027947; total time= 1.0min
# [CV] END activation=relu, alpha=0.00015597479536983742, batch_size=512, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.020597335357437203; total time=   4.8s
# [CV] END activation=relu, alpha=3.612478500429089, batch_size=128, hidden_layer_sizes=(32,), learning_rate=adaptive, learning_rate_init=0.038842777547031436; total time=   1.7s
# [CV] END activation=relu, alpha=0.003470634537133488, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.00010388823104027947; total time= 1.0min
# [CV] END activation=relu, alpha=3.612478500429089, batch_size=128, hidden_layer_sizes=(32,), learning_rate=adaptive, learning_rate_init=0.038842777547031436; total time=   3.3s
# [CV] END activation=relu, alpha=0.00015597479536983742, batch_size=512, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.020597335357437203; total time=   7.5s
# [CV] END activation=relu, alpha=3.612478500429089, batch_size=128, hidden_layer_sizes=(32,), learning_rate=adaptive, learning_rate_init=0.038842777547031436; total time=   2.2s
# [CV] END activation=relu, alpha=0.00015597479536983742, batch_size=512, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.020597335357437203; total time=   8.6s
# [CV] END activation=relu, alpha=3.612478500429089, batch_size=128, hidden_layer_sizes=(32,), learning_rate=adaptive, learning_rate_init=0.038842777547031436; total time=   2.6s
# [CV] END activation=relu, alpha=3.612478500429089, batch_size=128, hidden_layer_sizes=(32,), learning_rate=adaptive, learning_rate_init=0.038842777547031436; total time=   2.4s
# [CV] END activation=relu, alpha=0.003470634537133488, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.00010388823104027947; total time= 1.2min
# [CV] END activation=tanh, alpha=0.004973980116331517, batch_size=64, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.010151348978007608; total time=  13.9s
# [CV] END activation=tanh, alpha=0.004973980116331517, batch_size=64, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.010151348978007608; total time=  17.4s
# [CV] END activation=tanh, alpha=0.0004528924618383529, batch_size=64, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.00016736010167825804; total time= 1.8min
# [CV] END activation=tanh, alpha=0.004973980116331517, batch_size=64, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.010151348978007608; total time=  21.5s
# [CV] END activation=tanh, alpha=0.004973980116331517, batch_size=64, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.010151348978007608; total time=  20.9s
# [CV] END activation=tanh, alpha=0.004973980116331517, batch_size=64, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.010151348978007608; total time=  17.0s
# [CV] END activation=relu, alpha=0.2385816677142884, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.0048275888720946784; total time=   9.5s
# [CV] END activation=relu, alpha=5.2187377767381904e-05, batch_size=128, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.014628121654892834; total time=   5.6s
# [CV] END activation=tanh, alpha=0.0004528924618383529, batch_size=64, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.00016736010167825804; total time= 1.8min
# [CV] END activation=relu, alpha=0.2385816677142884, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.0048275888720946784; total time=  11.8s
# [CV] END activation=relu, alpha=0.2385816677142884, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.0048275888720946784; total time=   8.8s
# [CV] END activation=tanh, alpha=0.0004528924618383529, batch_size=64, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.00016736010167825804; total time= 1.8min
# [CV] END activation=relu, alpha=5.2187377767381904e-05, batch_size=128, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.014628121654892834; total time=   6.2s
# [CV] END activation=relu, alpha=0.2385816677142884, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.0048275888720946784; total time=   9.2s
# [CV] END activation=relu, alpha=0.2385816677142884, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.0048275888720946784; total time=   9.7s
# [CV] END activation=relu, alpha=0.42247700890263645, batch_size=256, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.01355154055297657; total time=   4.5s
# [CV] END activation=relu, alpha=5.2187377767381904e-05, batch_size=128, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.014628121654892834; total time=   6.1s
# [CV] END activation=relu, alpha=5.2187377767381904e-05, batch_size=128, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.014628121654892834; total time=   6.2s
# [CV] END activation=tanh, alpha=0.0004528924618383529, batch_size=64, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.00016736010167825804; total time= 2.0min
# [CV] END activation=relu, alpha=5.2187377767381904e-05, batch_size=128, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.014628121654892834; total time=   6.8s
# [CV] END activation=relu, alpha=0.42247700890263645, batch_size=256, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.01355154055297657; total time=   4.9s
# [CV] END activation=relu, alpha=0.42247700890263645, batch_size=256, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.01355154055297657; total time=   6.0s
# [CV] END activation=relu, alpha=0.42247700890263645, batch_size=256, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.01355154055297657; total time=   7.0s
# [CV] END activation=tanh, alpha=0.0004528924618383529, batch_size=64, hidden_layer_sizes=(256, 128, 64), learning_rate=constant, learning_rate_init=0.00016736010167825804; total time= 1.9min
# [CV] END activation=relu, alpha=0.42247700890263645, batch_size=256, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.01355154055297657; total time=   8.0s
# [CV] END activation=tanh, alpha=1.420740499067604e-05, batch_size=64, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.04867329944599207; total time=   7.0s
# [CV] END activation=tanh, alpha=1.420740499067604e-05, batch_size=64, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.04867329944599207; total time=  14.8s
# [CV] END activation=tanh, alpha=1.420740499067604e-05, batch_size=64, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.04867329944599207; total time=  14.5s
# [CV] END activation=tanh, alpha=1.420740499067604e-05, batch_size=64, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.04867329944599207; total time=  15.7s
# [CV] END activation=relu, alpha=0.0028993292583566945, batch_size=256, hidden_layer_sizes=(128, 64), learning_rate=adaptive, learning_rate_init=0.06738460883888428; total time=   9.5s
# [CV] END activation=relu, alpha=0.0028993292583566945, batch_size=256, hidden_layer_sizes=(128, 64), learning_rate=adaptive, learning_rate_init=0.06738460883888428; total time=   3.5s
# [CV] END activation=relu, alpha=0.0028993292583566945, batch_size=256, hidden_layer_sizes=(128, 64), learning_rate=adaptive, learning_rate_init=0.06738460883888428; total time=   5.7s
# [CV] END activation=relu, alpha=0.0028993292583566945, batch_size=256, hidden_layer_sizes=(128, 64), learning_rate=adaptive, learning_rate_init=0.06738460883888428; total time=   6.2s
# [CV] END activation=relu, alpha=0.0028993292583566945, batch_size=256, hidden_layer_sizes=(128, 64), learning_rate=adaptive, learning_rate_init=0.06738460883888428; total time=   7.7s
# [CV] END activation=relu, alpha=0.0007693711312648856, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0002618149026594374; total time=  20.4s
# [CV] END activation=tanh, alpha=1.420740499067604e-05, batch_size=64, hidden_layer_sizes=(128,), learning_rate=constant, learning_rate_init=0.04867329944599207; total time=  25.0s
# [CV] END activation=relu, alpha=0.0005476570938330316, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0074655557747457125; total time=   6.7s
# [CV] END activation=relu, alpha=0.0005476570938330316, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0074655557747457125; total time=   6.3s
# [CV] END activation=relu, alpha=0.0005476570938330316, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0074655557747457125; total time=   5.6s
# [CV] END activation=relu, alpha=0.0007693711312648856, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0002618149026594374; total time=  23.8s
# [CV] END activation=relu, alpha=0.0005476570938330316, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0074655557747457125; total time=   5.9s
# [CV] END activation=relu, alpha=0.0007693711312648856, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0002618149026594374; total time=  29.7s
# [CV] END activation=relu, alpha=0.0005476570938330316, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0074655557747457125; total time=   9.5s
# [CV] END activation=relu, alpha=0.0007693711312648856, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0002618149026594374; total time=  28.3s
# [CV] END activation=tanh, alpha=2.266490958666927, batch_size=256, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.04878360603452144; total time=   4.0s
# [CV] END activation=tanh, alpha=2.266490958666927, batch_size=256, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.04878360603452144; total time=   3.3s
# [CV] END activation=tanh, alpha=2.266490958666927, batch_size=256, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.04878360603452144; total time=   3.9s
# [CV] END activation=tanh, alpha=2.266490958666927, batch_size=256, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.04878360603452144; total time=   5.4s
# [CV] END activation=tanh, alpha=2.266490958666927, batch_size=256, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.04878360603452144; total time=   4.2s
# [CV] END activation=relu, alpha=0.0007693711312648856, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.0002618149026594374; total time=  36.0s
# [CV] END activation=tanh, alpha=0.06315715218918058, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.00045219037252571264; total time=  17.9s
# [CV] END activation=tanh, alpha=0.06315715218918058, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.00045219037252571264; total time=  21.1s
# [CV] END activation=tanh, alpha=0.06315715218918058, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.00045219037252571264; total time=  21.8s
# [CV] END activation=relu, alpha=2.760391295653, batch_size=64, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0019112758217777906; total time=  11.6s
# [CV] END activation=tanh, alpha=0.06315715218918058, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.00045219037252571264; total time=  19.5s
# [CV] END activation=tanh, alpha=0.06315715218918058, batch_size=128, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.00045219037252571264; total time=  21.4s
# [CV] END activation=relu, alpha=2.760391295653, batch_size=64, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0019112758217777906; total time=  12.6s
# [CV] END activation=relu, alpha=2.760391295653, batch_size=64, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0019112758217777906; total time=  15.9s
# [CV] END activation=relu, alpha=2.760391295653, batch_size=64, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0019112758217777906; total time=  15.7s
# [CV] END activation=relu, alpha=2.760391295653, batch_size=64, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0019112758217777906; total time=  16.0s
# [CV] END activation=tanh, alpha=0.0013044070518310998, batch_size=256, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.0034059785435329977; total time=  20.8s
# [CV] END activation=tanh, alpha=0.0013044070518310998, batch_size=256, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.0034059785435329977; total time=  24.0s
# [CV] END activation=tanh, alpha=0.0013044070518310998, batch_size=256, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.0034059785435329977; total time=  23.1s
# [CV] END activation=relu, alpha=0.008109233917023385, batch_size=64, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.0010300196600986776; total time=  21.1s
# [CV] END activation=tanh, alpha=0.0013044070518310998, batch_size=256, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.0034059785435329977; total time=  24.4s
# [CV] END activation=tanh, alpha=0.0013044070518310998, batch_size=256, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.0034059785435329977; total time=  25.5s
# [CV] END activation=relu, alpha=0.008109233917023385, batch_size=64, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.0010300196600986776; total time=  19.9s
# [CV] END activation=relu, alpha=0.008109233917023385, batch_size=64, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.0010300196600986776; total time=  23.9s
# [CV] END activation=relu, alpha=0.008109233917023385, batch_size=64, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.0010300196600986776; total time=  28.3s
# [CV] END activation=relu, alpha=0.00010226952834484176, batch_size=512, hidden_layer_sizes=(32,), learning_rate=adaptive, learning_rate_init=0.0012327891605450798; total time=  10.4s
# [CV] END activation=relu, alpha=0.00010226952834484176, batch_size=512, hidden_layer_sizes=(32,), learning_rate=adaptive, learning_rate_init=0.0012327891605450798; total time=  11.3s
# [CV] END activation=relu, alpha=0.008109233917023385, batch_size=64, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.0010300196600986776; total time=  30.3s
# [CV] END activation=relu, alpha=0.00010226952834484176, batch_size=512, hidden_layer_sizes=(32,), learning_rate=adaptive, learning_rate_init=0.0012327891605450798; total time=  11.2s
# [CV] END activation=relu, alpha=0.00033380472791196474, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.003102740950912841; total time=  10.1s
# [CV] END activation=relu, alpha=0.00033380472791196474, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.003102740950912841; total time=  10.1s
# [CV] END activation=relu, alpha=0.00010226952834484176, batch_size=512, hidden_layer_sizes=(32,), learning_rate=adaptive, learning_rate_init=0.0012327891605450798; total time=  12.9s
# [CV] END activation=relu, alpha=0.00010226952834484176, batch_size=512, hidden_layer_sizes=(32,), learning_rate=adaptive, learning_rate_init=0.0012327891605450798; total time=  12.5s
# [CV] END activation=relu, alpha=7.736091177936256e-05, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0067405137963740475; total time=   5.4s
# [CV] END activation=relu, alpha=7.736091177936256e-05, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0067405137963740475; total time=   4.2s
# [CV] END activation=relu, alpha=0.00033380472791196474, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.003102740950912841; total time=   7.0s
# [CV] END activation=relu, alpha=7.736091177936256e-05, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0067405137963740475; total time=   7.2s
# [CV] END activation=relu, alpha=0.00033380472791196474, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.003102740950912841; total time=   9.5s
# [CV] END activation=relu, alpha=7.736091177936256e-05, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0067405137963740475; total time=   4.9s
# [CV] END activation=tanh, alpha=0.002925648048608756, batch_size=256, hidden_layer_sizes=(128, 64), learning_rate=adaptive, learning_rate_init=0.05306371575220848; total time=   3.2s
# [CV] END activation=tanh, alpha=0.002925648048608756, batch_size=256, hidden_layer_sizes=(128, 64), learning_rate=adaptive, learning_rate_init=0.05306371575220848; total time=   2.6s
# [CV] END activation=tanh, alpha=0.002925648048608756, batch_size=256, hidden_layer_sizes=(128, 64), learning_rate=adaptive, learning_rate_init=0.05306371575220848; total time=   2.9s
# [CV] END activation=tanh, alpha=0.002925648048608756, batch_size=256, hidden_layer_sizes=(128, 64), learning_rate=adaptive, learning_rate_init=0.05306371575220848; total time=   3.9s
# [CV] END activation=tanh, alpha=0.002925648048608756, batch_size=256, hidden_layer_sizes=(128, 64), learning_rate=adaptive, learning_rate_init=0.05306371575220848; total time=   2.8s
# [CV] END activation=relu, alpha=0.00033380472791196474, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=constant, learning_rate_init=0.003102740950912841; total time=  13.9s
# [CV] END activation=relu, alpha=0.12140391985139702, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.09056311714376349; total time=   2.9s
# [CV] END activation=relu, alpha=0.12140391985139702, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.09056311714376349; total time=   3.2s
# [CV] END activation=relu, alpha=0.12140391985139702, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.09056311714376349; total time=   4.3s
# [CV] END activation=relu, alpha=0.12140391985139702, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.09056311714376349; total time=   3.0s
# [CV] END activation=relu, alpha=0.12140391985139702, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.09056311714376349; total time=   4.4s
# [CV] END activation=relu, alpha=7.736091177936256e-05, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0067405137963740475; total time=  10.6s
# [CV] END activation=relu, alpha=0.6589288735511766, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.007954064937683933; total time=   6.8s
# [CV] END activation=relu, alpha=0.6589288735511766, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.007954064937683933; total time=   7.0s
# [CV] END activation=relu, alpha=0.6589288735511766, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.007954064937683933; total time=   9.3s
# [CV] END activation=relu, alpha=0.6589288735511766, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.007954064937683933; total time=  11.3s
# [CV] END activation=relu, alpha=0.6589288735511766, batch_size=64, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.007954064937683933; total time=  11.4s
# [CV] END activation=relu, alpha=0.7917557741857993, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0009169384722192332; total time=  10.6s
# [CV] END activation=tanh, alpha=0.1495811406766844, batch_size=256, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.010781845035122271; total time=   1.6s
# [CV] END activation=tanh, alpha=0.1495811406766844, batch_size=256, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.010781845035122271; total time=   1.4s
# [CV] END activation=relu, alpha=0.7917557741857993, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0009169384722192332; total time=  12.3s
# [CV] END activation=tanh, alpha=0.1495811406766844, batch_size=256, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.010781845035122271; total time=   1.6s
# [CV] END activation=tanh, alpha=0.1495811406766844, batch_size=256, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.010781845035122271; total time=   1.7s
# [CV] END activation=tanh, alpha=0.1495811406766844, batch_size=256, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.010781845035122271; total time=   2.5s
# [CV] END activation=tanh, alpha=0.03598987541534457, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.000516312491048802; total time=  29.7s
# [CV] END activation=relu, alpha=0.7917557741857993, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0009169384722192332; total time=  20.9s
# [CV] END activation=relu, alpha=0.1848830915401361, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.008620220426018047; total time=   6.8s
# [CV] END activation=relu, alpha=0.1848830915401361, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.008620220426018047; total time=   7.6s
# [CV] END activation=relu, alpha=0.7917557741857993, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0009169384722192332; total time=  19.3s
# [CV] END activation=relu, alpha=0.7917557741857993, batch_size=512, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.0009169384722192332; total time=  18.3s
# [CV] END activation=relu, alpha=0.1848830915401361, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.008620220426018047; total time=   7.7s
# [CV] END activation=tanh, alpha=4.396829115666791, batch_size=512, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.03259344887239372; total time=   6.0s
# [CV] END activation=relu, alpha=0.1848830915401361, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.008620220426018047; total time=  10.6s
# [CV] END activation=tanh, alpha=4.396829115666791, batch_size=512, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.03259344887239372; total time=   6.3s
# [CV] END activation=tanh, alpha=0.03598987541534457, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.000516312491048802; total time=  41.6s
# [CV] END activation=relu, alpha=0.1848830915401361, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.008620220426018047; total time=  10.9s
# [CV] END activation=tanh, alpha=4.396829115666791, batch_size=512, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.03259344887239372; total time=   6.2s
# [CV] END activation=tanh, alpha=0.03598987541534457, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.000516312491048802; total time=  45.1s
# [CV] END activation=tanh, alpha=4.396829115666791, batch_size=512, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.03259344887239372; total time=  11.9s
# [CV] END activation=tanh, alpha=0.03598987541534457, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.000516312491048802; total time=  45.0s
# [CV] END activation=tanh, alpha=4.396829115666791, batch_size=512, hidden_layer_sizes=(256, 128, 64), learning_rate=adaptive, learning_rate_init=0.03259344887239372; total time=   5.6s
# [CV] END activation=relu, alpha=0.0011127512896771938, batch_size=64, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.004210599373265658; total time=   8.9s
# [CV] END activation=relu, alpha=0.0011127512896771938, batch_size=64, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.004210599373265658; total time=  10.8s
# [CV] END activation=relu, alpha=0.0011127512896771938, batch_size=64, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.004210599373265658; total time=   8.6s
# [CV] END activation=relu, alpha=0.0011127512896771938, batch_size=64, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.004210599373265658; total time=   9.0s
# [CV] END activation=tanh, alpha=0.03598987541534457, batch_size=256, hidden_layer_sizes=(128,), learning_rate=adaptive, learning_rate_init=0.000516312491048802; total time=  52.6s
# [CV] END activation=tanh, alpha=0.0003528984625415794, batch_size=512, hidden_layer_sizes=(64,), learning_rate=adaptive, learning_rate_init=0.004630228617122104; total time=   7.8s
# [CV] END activation=tanh, alpha=0.0003528984625415794, batch_size=512, hidden_layer_sizes=(64,), learning_rate=adaptive, learning_rate_init=0.004630228617122104; total time=   9.2s
# [CV] END activation=tanh, alpha=0.0003528984625415794, batch_size=512, hidden_layer_sizes=(64,), learning_rate=adaptive, learning_rate_init=0.004630228617122104; total time=   9.4s
# [CV] END activation=relu, alpha=0.0011127512896771938, batch_size=64, hidden_layer_sizes=(64,), learning_rate=constant, learning_rate_init=0.004210599373265658; total time=  11.3s
# [CV] END activation=tanh, alpha=0.0003528984625415794, batch_size=512, hidden_layer_sizes=(64,), learning_rate=adaptive, learning_rate_init=0.004630228617122104; total time=  11.1s
# [CV] END activation=tanh, alpha=0.0003528984625415794, batch_size=512, hidden_layer_sizes=(64,), learning_rate=adaptive, learning_rate_init=0.004630228617122104; total time=   6.3s
# [CV] END activation=tanh, alpha=0.06289393154519742, batch_size=64, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.012620410750629136; total time=   4.7s
# [CV] END activation=tanh, alpha=2.4135792291303972, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.04605855368582793; total time=   2.0s
# [CV] END activation=tanh, alpha=0.06289393154519742, batch_size=64, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.012620410750629136; total time=   6.3s
# [CV] END activation=tanh, alpha=0.06289393154519742, batch_size=64, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.012620410750629136; total time=   5.9s
# [CV] END activation=tanh, alpha=0.06289393154519742, batch_size=64, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.012620410750629136; total time=   8.0s
# [CV] END activation=tanh, alpha=0.06289393154519742, batch_size=64, hidden_layer_sizes=(32,), learning_rate=constant, learning_rate_init=0.012620410750629136; total time=   8.1s
# [CV] END activation=tanh, alpha=2.4135792291303972, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.04605855368582793; total time=   2.2s
# [CV] END activation=tanh, alpha=2.4135792291303972, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.04605855368582793; total time=   2.2s
# [CV] END activation=tanh, alpha=3.1977152637929994e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.01016166244341328; total time=   1.4s
# [CV] END activation=tanh, alpha=3.1977152637929994e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.01016166244341328; total time=   1.3s
# [CV] END activation=tanh, alpha=2.4135792291303972, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.04605855368582793; total time=   2.9s
# [CV] END activation=tanh, alpha=3.1977152637929994e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.01016166244341328; total time=   1.2s
# [CV] END activation=tanh, alpha=2.4135792291303972, batch_size=512, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.04605855368582793; total time=   3.6s
# [CV] END activation=tanh, alpha=3.1977152637929994e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.01016166244341328; total time=   5.6s
# [CV] END activation=tanh, alpha=3.1977152637929994e-05, batch_size=512, hidden_layer_sizes=(64, 32), learning_rate=adaptive, learning_rate_init=0.01016166244341328; total time=   5.6s
# [CV] END activation=tanh, alpha=0.00036726120005986903, batch_size=64, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.004730209334933687; total time=  20.9s
# [CV] END activation=tanh, alpha=0.00036726120005986903, batch_size=64, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.004730209334933687; total time=  21.7s
# [CV] END activation=tanh, alpha=0.00036726120005986903, batch_size=64, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.004730209334933687; total time=  21.3s
# [CV] END activation=tanh, alpha=0.00036726120005986903, batch_size=64, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.004730209334933687; total time=  23.1s
# [CV] END activation=tanh, alpha=0.00036726120005986903, batch_size=64, hidden_layer_sizes=(128, 64, 32), learning_rate=adaptive, learning_rate_init=0.004730209334933687; total time=  24.5s
#
# Best parameters (ANN):
# {'activation': 'tanh', 'alpha': np.float64(0.0004528924618383529), 'batch_size': 64, 'hidden_layer_sizes': (256, 128, 64), 'learning_rate': 'constant', 'learning_rate_init': np.float64(0.00016736010167825804)}
# Best CV MSE (negative): -319.0368

# %% [markdown]
# ### Train Optimized ANN

# %%
y_test_arr = np.ravel(y_test)

# Train final model on full training data with best params (optional but recommended)
best_ann = ann_random_search.best_estimator_
best_ann.fit(X_train_scaled, y_train_arr)

# Evaluate on test data
y_pred_ann = best_ann.predict(X_test_scaled)
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
mse_ann = mean_squared_error(y_test_arr, y_pred_ann)
r2_ann = r2_score(y_test_arr, y_pred_ann)
print(f"\nANN (best hyperparams) MSE: {mse_ann:.2f}")
print(f"ANN (best hyperparams) R²: {r2_ann:.3f}")

mse_ann = mean_squared_error(y_test_arr, y_pred_ann)
mae_ann = mean_absolute_error(y_test_arr, y_pred_ann)
rmse_ann = np.sqrt(mse_ann)
r2_ann = r2_score(y_test_arr, y_pred_ann)

print("\nArtificial Neural Network (MLPRegressor)")
print(f"MAE :  {mae_ann:.4f}")
print(f"RMSE:  {rmse_ann:.4f}")
print(f"R^2 :  {r2_ann:.4f}")
# Out:
# ANN (best hyperparams) MSE: 311.46
# ANN (best hyperparams) R²: 0.260
#
# Artificial Neural Network (MLPRegressor)
# MAE :  13.4354
# RMSE:  17.6482
# R^2 :  0.2596

# %% [markdown]
# ### Plot Optimized ANN

# %%
# VISUALIZATION: Predicted vs Actual

plt.figure(figsize=(8, 6))
plt.scatter(y_test_arr, y_pred_ann, alpha=0.6, edgecolors="k", linewidth=0.5)
min_val = min(y_test_arr.min(), y_pred_ann.min())
max_val = max(y_test_arr.max(), y_pred_ann.max())
plt.plot([min_val, max_val], [min_val, max_val], "r--", lw=2, label="Perfect Prediction")
plt.xlabel("True Popularity", fontsize=12)
plt.ylabel("Predicted Popularity (ANN)", fontsize=12)
plt.title(f"ANN Regression\nGlobal R² = {r2_ann:.3f}", fontsize=14)
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# VISUALIZATION: Training Loss Curve

plt.figure(figsize=(10, 6))
plt.plot(best_ann.loss_curve_, linewidth=2)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss (MSE)', fontsize=12)
plt.title('ANN Training Loss Over Epochs', fontsize=14)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
