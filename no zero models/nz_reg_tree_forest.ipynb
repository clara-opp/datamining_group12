# %% [markdown]
# # Regression Tree

# %% [markdown]
# ## Regular Training (with popularity scores of 0)

# %% [markdown]
# ### Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils_io import load_step, save_step
from sklearn.tree import DecisionTreeRegressor, export_text
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, KFold, RandomizedSearchCV

# %%
y_train = load_step("y_train_nz")
y_test = load_step("y_test_nz")
X_train = load_step("X_train_nz")
X_test = load_step("X_test_nz")
X_train_scaled = load_step("X_train_nz_scaled")
X_test_scaled = load_step("X_test_nz_scaled")

# %% [markdown]
# ### Random Forest with Regression Trees

# %% [markdown]
# #### Random Forest -Unscaled Data-

# %%
# Random Forest Regressor 
rf = RandomForestRegressor(
    n_estimators=200,        # number of trees
    max_depth=40,           
#    min_samples_split=3,     # min samples to split
    min_samples_leaf=1,      # min samples per leaf
    max_features=15,     # features per split
    random_state=42,
    n_jobs=-1
)

# train
rf.fit(X_train, y_train)

# pred
y_pred = rf.predict(X_test)

# performance
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Random Forest MSE: {mse:.2f}")
print(f"Random Forest R²: {r2:.3f}")

# feature importance
importances = pd.Series(rf.feature_importances_, index=X_train.columns)
importances = importances.sort_values(ascending=False)
print("\nTop 10 Important Features:")
print(importances.head(10))
# Out:
# /Users/clari/datamining_group12/venv/lib/python3.14/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Random Forest MSE: 215.52
# Random Forest R²: 0.339
#
# Top 10 Important Features:
# acousticness        0.080025
# duration_ms         0.077995
# instrumentalness    0.076571
# energy              0.070804
# loudness            0.070764
# danceability        0.070062
# speechiness         0.069477
# valence             0.067168
# tempo               0.060175
# liveness            0.055242
# dtype: float64

# %% [markdown]
# #### Random Forest -Scaled Data-

# %%
rf_scaled = RandomForestRegressor(
    n_estimators=200,        # number of trees
    max_depth=40,            
#    min_samples_split=3,     # min samples to split
    min_samples_leaf=1,      # min samples per leaf
    max_features=15,     # features per split
    random_state=42,
    n_jobs=-1
)

# train
rf_scaled.fit(X_train_scaled, y_train)

# pred
y_pred_scaled = rf_scaled.predict(X_test_scaled)

# performance
mse_scaled = mean_squared_error(y_test, y_pred_scaled)
r2_scaled = r2_score(y_test, y_pred_scaled)

print(f"Random Forest (scaled) MSE: {mse_scaled:.2f}")
print(f"Random Forest (scaled) R²: {r2_scaled:.3f}")

# feature importance
importances_scaled = pd.Series(rf_scaled.feature_importances_, index=X_train_scaled.columns)
importances_scaled = importances_scaled.sort_values(ascending=False)
print("\nTop 10 wichtige Features (scaled):")
print(importances_scaled.head(10))
# Out:
# /Users/clari/datamining_group12/venv/lib/python3.14/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Random Forest (scaled) MSE: 215.52
# Random Forest (scaled) R²: 0.339
#
# Top 10 wichtige Features (scaled):
# acousticness        0.080025
# duration_ms         0.077995
# instrumentalness    0.076571
# energy              0.070804
# loudness            0.070764
# danceability        0.070062
# speechiness         0.069477
# valence             0.067168
# tempo               0.060175
# liveness            0.055242
# dtype: float64

# %% [markdown]
# ### Regression Tree

# %% [markdown]
# #### Regression tree -Unscaled Data-

# %%
# Initialize Regressor
regressor = DecisionTreeRegressor(max_depth=16, min_samples_split=8, min_samples_leaf=80) # Before Optimization: none, 20, 20 #

# Fitting the Regressor
regressor.fit(X_train, y_train)

# Predict the Popularity
y_pred = regressor.predict(X_test)

# What do the metrics say about our model?
print
print(f"Mean Squared Error: ", mean_squared_error(y_test, y_pred))
print(f"Mean Absolute Error: ", mean_absolute_error(y_test, y_pred))
print(f"R²: ", r2_score(y_test, y_pred))

# --- Before Optimization---  #

# Mean Squared Error:  366.9908745841802
# Mean Absolute Error:  14.545597567963474
# R²:  0.12762439147810323

# --- After Optimization---  #

# Mean Squared Error:  345.68702352872225
# Mean Absolute Error:  14.435585852955738
# R²:  0.17826586873396877
# Out:
# Mean Squared Error:  254.61401303780775
# Mean Absolute Error:  12.431076831691088
# R²:  0.21889028728697335

# %% [markdown]
# #### Regression tree -Scaled Data-

# %%
# Initialize Regressor
regressor = DecisionTreeRegressor(max_depth=16, min_samples_split=80, min_samples_leaf=8) # Before Optimization: none, 20, 20 #

# Fitting the Regressor
regressor.fit(X_train_scaled, y_train)

# Predict the Popularity
y_pred_scaled = regressor.predict(X_test_scaled)

# What do the metrics say about the model?
print(f"Mean Squared Error: ", mean_squared_error(y_test, y_pred_scaled))
print(f"Mean Absolute Error: ", mean_absolute_error(y_test, y_pred_scaled))
print(f"R²: ", r2_score(y_test, y_pred))

# --- Before Optimization---  #
# Mean Squared Error:  366.9908745841802
# Mean Absolute Error:  14.545597567963474
# R²:  0.12762439147810323

# --- After Optimization---  #
# Mean Squared Error:  345.68702352872225
# Mean Absolute Error:  14.435585852955738
# R²:  0.17826586873396877
# Out:
# Mean Squared Error:  259.5679185620503
# Mean Absolute Error:  12.360703254383905
# R²:  0.21889028728697335

# %% [markdown]
# ### Visualization - Random forest

# %%
# How did we do?
y_pred_scaled = rf_scaled.predict(X_test_scaled)

plt.scatter(y_test, y_pred_scaled, alpha=0.4)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Predicted vs Actual (scaled)")
plt.show()

# %% [markdown]
# ### Visualization - Regression tree

# %%
# How did we do?
y_pred = regressor.predict(X_test_scaled)

plt.scatter(y_test, y_pred, alpha=0.4)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Predicted vs Actual")
plt.show()

# %% [markdown]
# ## Hyperparameter Optimization

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import KFold, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# 1) Define the base model (no min_samples_split tuned)
base_tree = DecisionTreeRegressor(
    random_state=42
)

# 2) Define the hyperparameter search space
param_dist = {
    "max_depth": [None, 3, 5, 7, 9],
    "min_samples_leaf": [5, 10, 20, 50, 100, 200]
}

# 3) Cross-validation strategy
cv = KFold(n_splits=5, shuffle=True, random_state=42)

# 4) Random search (neg MSE because sklearn wants "higher is better")
rand_search = RandomizedSearchCV(
    estimator=base_tree,
    param_distributions=param_dist,
    n_iter=30,                          # number of random configs to try
    scoring="neg_mean_squared_error",   # or "r2" if you prefer
    cv=cv,
    n_jobs=-1,
    random_state=42,
    verbose=1
)

# 5) Run the search
rand_search.fit(X_train_scaled, np.ravel(y_train))

print("Best params:", rand_search.best_params_)
print("Best CV score (neg MSE):", rand_search.best_score_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best params: {'min_samples_leaf': 100, 'max_depth': None}
# Best CV score (neg MSE): -265.3854301222029

# %%
# 6) Evaluate the best model on the test set
best_tree = rand_search.best_estimator_

y_pred_test = best_tree.predict(X_test_scaled)

mae = mean_absolute_error(y_test, y_pred_test)
r2  = r2_score(y_test, y_pred_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))


print("\n=== Test set performance of best random-search tree ===")
print(f"Mean Absolute Error: {mae:.4f}")
print(f"  RMSE: {rmse:.4f}")
print(f"R²:                  {r2:.4f}")
# Out:
# === Test set performance of best random-search tree ===
# Mean Absolute Error: 12.4922
#   RMSE: 15.9975
# R²:                  0.2149

# %%
# rules = export_text(best_tree, feature_names=list(X_train_scaled.columns))
# print(rules)

from sklearn.tree import export_text

short_rules = export_text(best_tree, feature_names=list(X_train_scaled.columns), max_depth=3)
print(short_rules)
# Out:
# |--- instrumentalness <= 0.03
# |   |--- genre__Country_Americana <= 0.50
# |   |   |--- genre__Mood_Functional_Other <= 0.50
# |   |   |   |--- energy <= 0.92
# |   |   |   |   |--- truncated branch of depth 22
# |   |   |   |--- energy >  0.92
# |   |   |   |   |--- truncated branch of depth 12
# |   |   |--- genre__Mood_Functional_Other >  0.50
# |   |   |   |--- energy <= 0.68
# |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |--- energy >  0.68
# |   |   |   |   |--- truncated branch of depth 8
# |   |--- genre__Country_Americana >  0.50
# |   |   |--- acousticness <= 0.40
# |   |   |   |--- instrumentalness <= 0.00
# |   |   |   |   |--- value: [37.57]
# |   |   |   |--- instrumentalness >  0.00
# |   |   |   |   |--- truncated branch of depth 2
# |   |   |--- acousticness >  0.40
# |   |   |   |--- duration_ms <= 0.19
# |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |--- duration_ms >  0.19
# |   |   |   |   |--- truncated branch of depth 4
# |--- instrumentalness >  0.03
# |   |--- genre__Rock <= 0.50
# |   |   |--- duration_ms <= 0.45
# |   |   |   |--- loudness <= 0.39
# |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |--- loudness >  0.39
# |   |   |   |   |--- truncated branch of depth 16
# |   |   |--- duration_ms >  0.45
# |   |   |   |--- valence <= 0.37
# |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |--- valence >  0.37
# |   |   |   |   |--- truncated branch of depth 5
# |   |--- genre__Rock >  0.50
# |   |   |--- energy <= 0.79
# |   |   |   |--- liveness <= 0.12
# |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |--- liveness >  0.12
# |   |   |   |   |--- truncated branch of depth 3
# |   |   |--- energy >  0.79
# |   |   |   |--- acousticness <= 0.01
# |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |--- acousticness >  0.01
# |   |   |   |   |--- value: [43.03]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV, KFold
from scipy.stats import randint, uniform

# -----------------------------------------------
# HYPERPARAMETER OPTIMIZATION FOR RANDOM FOREST
# -----------------------------------------------

# ensure y is 1D
y_train_arr = np.ravel(y_train)
y_test_arr = np.ravel(y_test)

# Parameter distributions for RANDOM SEARCH
param_dist = {
    "max_depth": [None, 3, 5, 7, 9],  # None + depths {5, 10, 15, 20, 25, 30, 35, 40}
    "min_samples_leaf": [5, 10, 20, 50, 100, 200],        # smaller leaves good for RF
    "max_features": uniform(loc=0.1, scale=0.9),  # consistent with sklearn RF "auto", "sqrt", 0.2, 0.5, 0.8
}

# 5-Fold CV
cv = KFold(n_splits=5, shuffle=True, random_state=42)

# RandomizedSearchCV setup
random_search = RandomizedSearchCV(
    estimator=RandomForestRegressor(n_estimators=200, min_samples_split=2, random_state=42, n_jobs=-1),
    param_distributions=param_dist,
    n_iter=200,                             # Number of random combinations to try
    scoring="neg_mean_squared_error",
    cv=cv,
    n_jobs=-1,
    verbose=2,
    random_state=42
)

#print("Running Random Search for Random Forest...")
random_search.fit(X_train_scaled, y_train_arr)

print("\nBest params:", random_search.best_params_)
print("Best CV score (neg MSE):", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [CV] END max_depth=9, max_features=0.6371651421518383, min_samples_leaf=10; total time=  35.0s
# [CV] END max_depth=9, max_features=0.6371651421518383, min_samples_leaf=10; total time=  35.3s
# [CV] END max_depth=9, max_features=0.6371651421518383, min_samples_leaf=10; total time=  35.3s
# [CV] END max_depth=9, max_features=0.6371651421518383, min_samples_leaf=10; total time=  35.5s
# [CV] END max_depth=9, max_features=0.6371651421518383, min_samples_leaf=10; total time=  35.7s
# [CV] END max_depth=7, max_features=0.9556428757689246, min_samples_leaf=20; total time=  40.3s
# [CV] END max_depth=7, max_features=0.9556428757689246, min_samples_leaf=20; total time=  40.3s
# [CV] END max_depth=5, max_features=0.18997742423620262, min_samples_leaf=20; total time=   5.4s
# [CV] END max_depth=7, max_features=0.9556428757689246, min_samples_leaf=20; total time=  40.5s
# [CV] END max_depth=5, max_features=0.18997742423620262, min_samples_leaf=20; total time=   5.4s
# [CV] END max_depth=7, max_features=0.9556428757689246, min_samples_leaf=20; total time=  40.7s
# [CV] END max_depth=7, max_features=0.9556428757689246, min_samples_leaf=20; total time=  40.8s
# [CV] END max_depth=5, max_features=0.18997742423620262, min_samples_leaf=20; total time=   5.7s
# [CV] END max_depth=5, max_features=0.18997742423620262, min_samples_leaf=20; total time=   5.5s
# [CV] END max_depth=5, max_features=0.18997742423620262, min_samples_leaf=20; total time=   5.7s
# [CV] END max_depth=9, max_features=0.6410035105688879, min_samples_leaf=20; total time=  38.3s
# [CV] END max_depth=9, max_features=0.6410035105688879, min_samples_leaf=20; total time=  38.4s
# [CV] END max_depth=9, max_features=0.6410035105688879, min_samples_leaf=20; total time=  38.3s
# [CV] END max_depth=9, max_features=0.6410035105688879, min_samples_leaf=20; total time=  38.6s
# [CV] END max_depth=9, max_features=0.6410035105688879, min_samples_leaf=20; total time=  38.9s
# [CV] END max_depth=3, max_features=0.26364247048639056, min_samples_leaf=100; total time=   5.2s
# [CV] END max_depth=3, max_features=0.26364247048639056, min_samples_leaf=100; total time=   5.4s
# [CV] END max_depth=3, max_features=0.26364247048639056, min_samples_leaf=100; total time=   5.6s
# [CV] END max_depth=3, max_features=0.26364247048639056, min_samples_leaf=100; total time=   5.4s
# [CV] END max_depth=3, max_features=0.26364247048639056, min_samples_leaf=100; total time=   5.5s
# [CV] END max_depth=9, max_features=0.9729188669457949, min_samples_leaf=50; total time=  54.9s
# [CV] END max_depth=9, max_features=0.9729188669457949, min_samples_leaf=50; total time=  55.3s
# [CV] END max_depth=9, max_features=0.9729188669457949, min_samples_leaf=50; total time=  55.3s
# [CV] END max_depth=9, max_features=0.9729188669457949, min_samples_leaf=50; total time=  55.7s
# [CV] END max_depth=9, max_features=0.9729188669457949, min_samples_leaf=50; total time=  55.5s
# [CV] END max_depth=None, max_features=0.373818018663584, min_samples_leaf=200; total time=  25.9s
# [CV] END max_depth=None, max_features=0.373818018663584, min_samples_leaf=200; total time=  26.0s
# [CV] END max_depth=None, max_features=0.373818018663584, min_samples_leaf=200; total time=  26.5s
# [CV] END max_depth=None, max_features=0.373818018663584, min_samples_leaf=200; total time=  26.9s
# [CV] END max_depth=None, max_features=0.373818018663584, min_samples_leaf=200; total time=  26.9s
# [CV] END max_depth=9, max_features=0.48875051677790415, min_samples_leaf=5; total time=  29.2s
# [CV] END max_depth=9, max_features=0.48875051677790415, min_samples_leaf=5; total time=  28.9s
# [CV] END max_depth=9, max_features=0.48875051677790415, min_samples_leaf=5; total time=  29.4s
# [CV] END max_depth=9, max_features=0.48875051677790415, min_samples_leaf=5; total time=  29.1s
# [CV] END max_depth=9, max_features=0.48875051677790415, min_samples_leaf=5; total time=  29.1s
# [CV] END max_depth=5, max_features=0.6506676052501416, min_samples_leaf=10; total time=  21.6s
# [CV] END max_depth=5, max_features=0.6506676052501416, min_samples_leaf=10; total time=  21.6s
# [CV] END max_depth=5, max_features=0.6506676052501416, min_samples_leaf=10; total time=  21.7s
# [CV] END max_depth=5, max_features=0.6506676052501416, min_samples_leaf=10; total time=  21.5s
# [CV] END max_depth=5, max_features=0.6506676052501416, min_samples_leaf=10; total time=  21.7s
# [CV] END max_depth=5, max_features=0.4442157921404465, min_samples_leaf=50; total time=  13.6s
# [CV] END max_depth=5, max_features=0.4442157921404465, min_samples_leaf=50; total time=  14.0s
# [CV] END max_depth=5, max_features=0.4442157921404465, min_samples_leaf=50; total time=  13.6s
# [CV] END max_depth=5, max_features=0.4442157921404465, min_samples_leaf=50; total time=  13.7s
# [CV] END max_depth=5, max_features=0.4442157921404465, min_samples_leaf=50; total time=  13.5s
# [CV] END max_depth=None, max_features=0.14180537144799796, min_samples_leaf=20; total time=  14.7s
# [CV] END max_depth=None, max_features=0.14180537144799796, min_samples_leaf=20; total time=  14.7s
# [CV] END max_depth=None, max_features=0.14180537144799796, min_samples_leaf=20; total time=  14.6s
# [CV] END max_depth=None, max_features=0.14180537144799796, min_samples_leaf=20; total time=  14.6s
# [CV] END max_depth=None, max_features=0.14180537144799796, min_samples_leaf=20; total time=  14.7s
# [CV] END max_depth=7, max_features=0.9763799669573132, min_samples_leaf=200; total time=  40.0s
# [CV] END max_depth=7, max_features=0.9763799669573132, min_samples_leaf=200; total time=  40.0s
# [CV] END max_depth=7, max_features=0.9763799669573132, min_samples_leaf=200; total time=  39.8s
# [CV] END max_depth=7, max_features=0.9763799669573132, min_samples_leaf=200; total time=  40.2s
# [CV] END max_depth=7, max_features=0.9763799669573132, min_samples_leaf=200; total time=  40.7s
# [CV] END max_depth=9, max_features=0.5054493267725887, min_samples_leaf=10; total time=  27.6s
# [CV] END max_depth=9, max_features=0.5054493267725887, min_samples_leaf=10; total time=  27.8s
# [CV] END max_depth=9, max_features=0.5054493267725887, min_samples_leaf=10; total time=  27.4s
# [CV] END max_depth=9, max_features=0.5054493267725887, min_samples_leaf=10; total time=  27.1s
# [CV] END max_depth=9, max_features=0.5054493267725887, min_samples_leaf=10; total time=  27.2s
# [CV] END max_depth=3, max_features=0.4468748522859245, min_samples_leaf=10; total time=   8.3s
# [CV] END max_depth=3, max_features=0.4468748522859245, min_samples_leaf=10; total time=   8.5s
# [CV] END max_depth=3, max_features=0.4468748522859245, min_samples_leaf=10; total time=   8.8s
# [CV] END max_depth=3, max_features=0.4468748522859245, min_samples_leaf=10; total time=   8.6s
# [CV] END max_depth=3, max_features=0.4468748522859245, min_samples_leaf=10; total time=   8.6s
# [CV] END max_depth=7, max_features=0.9479815801163675, min_samples_leaf=200; total time=  37.2s
# [CV] END max_depth=7, max_features=0.9479815801163675, min_samples_leaf=200; total time=  37.6s
# [CV] END max_depth=7, max_features=0.9479815801163675, min_samples_leaf=200; total time=  37.9s
# [CV] END max_depth=7, max_features=0.9479815801163675, min_samples_leaf=200; total time=  37.9s
# [CV] END max_depth=7, max_features=0.9479815801163675, min_samples_leaf=200; total time=  37.8s
# [CV] END max_depth=7, max_features=0.20983441136030095, min_samples_leaf=100; total time=   9.9s
# [CV] END max_depth=7, max_features=0.20983441136030095, min_samples_leaf=100; total time=   9.9s
# [CV] END max_depth=7, max_features=0.20983441136030095, min_samples_leaf=100; total time=   9.8s
# [CV] END max_depth=7, max_features=0.20983441136030095, min_samples_leaf=100; total time=   9.7s
# [CV] END max_depth=9, max_features=0.3078044430599341, min_samples_leaf=50; total time=  17.3s
# [CV] END max_depth=9, max_features=0.3078044430599341, min_samples_leaf=50; total time=  17.5s
# [CV] END max_depth=7, max_features=0.20983441136030095, min_samples_leaf=100; total time=   9.5s
# [CV] END max_depth=9, max_features=0.3078044430599341, min_samples_leaf=50; total time=  17.4s
# [CV] END max_depth=9, max_features=0.3078044430599341, min_samples_leaf=50; total time=  17.8s
# [CV] END max_depth=9, max_features=0.3078044430599341, min_samples_leaf=50; total time=  17.3s
# [CV] END max_depth=3, max_features=0.6962700559185838, min_samples_leaf=10; total time=  13.6s
# [CV] END max_depth=3, max_features=0.6962700559185838, min_samples_leaf=10; total time=  13.7s
# [CV] END max_depth=3, max_features=0.6962700559185838, min_samples_leaf=10; total time=  13.6s
# [CV] END max_depth=3, max_features=0.6962700559185838, min_samples_leaf=10; total time=  13.6s
# [CV] END max_depth=3, max_features=0.6962700559185838, min_samples_leaf=10; total time=  13.7s
# [CV] END max_depth=3, max_features=0.6109302950379923, min_samples_leaf=100; total time=  12.7s
# [CV] END max_depth=3, max_features=0.6109302950379923, min_samples_leaf=100; total time=  12.9s
# [CV] END max_depth=3, max_features=0.6109302950379923, min_samples_leaf=100; total time=  12.6s
# [CV] END max_depth=3, max_features=0.6109302950379923, min_samples_leaf=100; total time=  12.9s
# [CV] END max_depth=3, max_features=0.6109302950379923, min_samples_leaf=100; total time=  12.8s
# [CV] END max_depth=5, max_features=0.9183883618709039, min_samples_leaf=50; total time=  29.9s
# [CV] END max_depth=5, max_features=0.9183883618709039, min_samples_leaf=50; total time=  30.1s
# [CV] END max_depth=5, max_features=0.9183883618709039, min_samples_leaf=50; total time=  30.6s
# [CV] END max_depth=5, max_features=0.9183883618709039, min_samples_leaf=50; total time=  30.4s
# [CV] END max_depth=5, max_features=0.9183883618709039, min_samples_leaf=50; total time=  30.5s
# [CV] END max_depth=3, max_features=0.7976195410250031, min_samples_leaf=10; total time=  15.7s
# [CV] END max_depth=3, max_features=0.7976195410250031, min_samples_leaf=10; total time=  15.6s
# [CV] END max_depth=3, max_features=0.7976195410250031, min_samples_leaf=10; total time=  15.6s
# [CV] END max_depth=3, max_features=0.7976195410250031, min_samples_leaf=10; total time=  15.4s
# [CV] END max_depth=3, max_features=0.7976195410250031, min_samples_leaf=10; total time=  15.7s
# [CV] END max_depth=3, max_features=0.905344615384884, min_samples_leaf=200; total time=  17.2s
# [CV] END max_depth=3, max_features=0.905344615384884, min_samples_leaf=200; total time=  17.3s
# [CV] END max_depth=3, max_features=0.905344615384884, min_samples_leaf=200; total time=  17.3s
# [CV] END max_depth=3, max_features=0.905344615384884, min_samples_leaf=200; total time=  17.2s
# [CV] END max_depth=3, max_features=0.905344615384884, min_samples_leaf=200; total time=  17.4s
# [CV] END max_depth=7, max_features=0.14070456001948428, min_samples_leaf=100; total time=   5.8s
# [CV] END max_depth=7, max_features=0.14070456001948428, min_samples_leaf=100; total time=   5.9s
# [CV] END max_depth=7, max_features=0.14070456001948428, min_samples_leaf=100; total time=   5.9s
# [CV] END max_depth=7, max_features=0.14070456001948428, min_samples_leaf=100; total time=   5.8s
# [CV] END max_depth=7, max_features=0.14070456001948428, min_samples_leaf=100; total time=   5.9s
# [CV] END max_depth=9, max_features=0.34421412859650635, min_samples_leaf=100; total time=  18.2s
# [CV] END max_depth=9, max_features=0.34421412859650635, min_samples_leaf=100; total time=  18.2s
# [CV] END max_depth=9, max_features=0.34421412859650635, min_samples_leaf=100; total time=  18.7s
# [CV] END max_depth=9, max_features=0.34421412859650635, min_samples_leaf=100; total time=  18.2s
# [CV] END max_depth=3, max_features=0.9687297765377242, min_samples_leaf=50; total time=  18.0s
# [CV] END max_depth=9, max_features=0.34421412859650635, min_samples_leaf=100; total time=  18.6s
# [CV] END max_depth=3, max_features=0.9687297765377242, min_samples_leaf=50; total time=  17.6s
# [CV] END max_depth=3, max_features=0.9687297765377242, min_samples_leaf=50; total time=  17.7s
# [CV] END max_depth=3, max_features=0.9687297765377242, min_samples_leaf=50; total time=  17.5s
# [CV] END max_depth=3, max_features=0.9687297765377242, min_samples_leaf=50; total time=  17.8s
# [CV] END max_depth=9, max_features=0.16709557931179375, min_samples_leaf=5; total time=   9.2s
# [CV] END max_depth=9, max_features=0.16709557931179375, min_samples_leaf=5; total time=   9.1s
# [CV] END max_depth=9, max_features=0.16709557931179375, min_samples_leaf=5; total time=   9.3s
# [CV] END max_depth=9, max_features=0.16709557931179375, min_samples_leaf=5; total time=   9.4s
# [CV] END max_depth=9, max_features=0.16709557931179375, min_samples_leaf=5; total time=   9.3s
# [CV] END max_depth=7, max_features=0.3483992638202891, min_samples_leaf=100; total time=  15.6s
# [CV] END max_depth=7, max_features=0.3483992638202891, min_samples_leaf=100; total time=  15.3s
# [CV] END max_depth=7, max_features=0.3483992638202891, min_samples_leaf=100; total time=  15.3s
# [CV] END max_depth=7, max_features=0.3483992638202891, min_samples_leaf=100; total time=  15.3s
# [CV] END max_depth=7, max_features=0.3483992638202891, min_samples_leaf=100; total time=  15.8s
# [CV] END max_depth=5, max_features=0.7361716094628554, min_samples_leaf=20; total time=  26.1s
# [CV] END max_depth=5, max_features=0.7361716094628554, min_samples_leaf=20; total time=  25.7s
# [CV] END max_depth=5, max_features=0.7361716094628554, min_samples_leaf=20; total time=  25.8s
# [CV] END max_depth=5, max_features=0.7361716094628554, min_samples_leaf=20; total time=  25.4s
# [CV] END max_depth=None, max_features=0.2788441133807552, min_samples_leaf=20; total time=  31.5s
# [CV] END max_depth=None, max_features=0.2788441133807552, min_samples_leaf=20; total time=  31.6s
# [CV] END max_depth=5, max_features=0.7361716094628554, min_samples_leaf=20; total time=  25.6s
# [CV] END max_depth=None, max_features=0.2788441133807552, min_samples_leaf=20; total time=  31.8s
# [CV] END max_depth=None, max_features=0.2788441133807552, min_samples_leaf=20; total time=  32.0s
# [CV] END max_depth=None, max_features=0.2788441133807552, min_samples_leaf=20; total time=  31.7s
# [CV] END max_depth=3, max_features=0.4226191556898453, min_samples_leaf=5; total time=   8.0s
# [CV] END max_depth=3, max_features=0.4226191556898453, min_samples_leaf=5; total time=   7.8s
# [CV] END max_depth=3, max_features=0.4226191556898453, min_samples_leaf=5; total time=   7.8s
# [CV] END max_depth=3, max_features=0.4226191556898453, min_samples_leaf=5; total time=   7.9s
# [CV] END max_depth=3, max_features=0.4226191556898453, min_samples_leaf=5; total time=   7.9s
# [CV] END max_depth=5, max_features=0.7941433120173511, min_samples_leaf=100; total time=  24.6s
# [CV] END max_depth=5, max_features=0.7941433120173511, min_samples_leaf=100; total time=  24.4s
# [CV] END max_depth=5, max_features=0.7941433120173511, min_samples_leaf=100; total time=  24.1s
# [CV] END max_depth=5, max_features=0.7941433120173511, min_samples_leaf=100; total time=  24.3s
# [CV] END max_depth=5, max_features=0.7941433120173511, min_samples_leaf=100; total time=  24.4s
# [CV] END max_depth=3, max_features=0.1858691048413702, min_samples_leaf=200; total time=   3.6s
# [CV] END max_depth=3, max_features=0.1858691048413702, min_samples_leaf=200; total time=   3.8s
# [CV] END max_depth=3, max_features=0.1858691048413702, min_samples_leaf=200; total time=   3.8s
# [CV] END max_depth=3, max_features=0.1858691048413702, min_samples_leaf=200; total time=   3.7s
# [CV] END max_depth=3, max_features=0.1858691048413702, min_samples_leaf=200; total time=   3.8s
# [CV] END max_depth=7, max_features=0.8767930832880342, min_samples_leaf=50; total time=  37.8s
# [CV] END max_depth=7, max_features=0.8767930832880342, min_samples_leaf=50; total time=  37.7s
# [CV] END max_depth=7, max_features=0.8767930832880342, min_samples_leaf=50; total time=  38.0s
# [CV] END max_depth=7, max_features=0.8767930832880342, min_samples_leaf=50; total time=  37.8s
# [CV] END max_depth=7, max_features=0.8767930832880342, min_samples_leaf=50; total time=  37.7s
# [CV] END max_depth=9, max_features=0.7566455605042577, min_samples_leaf=200; total time=  35.9s
# [CV] END max_depth=9, max_features=0.7566455605042577, min_samples_leaf=200; total time=  36.1s
# [CV] END max_depth=9, max_features=0.7566455605042577, min_samples_leaf=200; total time=  36.4s
# [CV] END max_depth=5, max_features=0.6051190832629311, min_samples_leaf=20; total time=  18.1s
# [CV] END max_depth=9, max_features=0.7566455605042577, min_samples_leaf=200; total time=  36.8s
# [CV] END max_depth=5, max_features=0.6051190832629311, min_samples_leaf=20; total time=  18.2s
# [CV] END max_depth=5, max_features=0.6051190832629311, min_samples_leaf=20; total time=  18.3s
# [CV] END max_depth=5, max_features=0.6051190832629311, min_samples_leaf=20; total time=  18.1s
# [CV] END max_depth=5, max_features=0.6051190832629311, min_samples_leaf=20; total time=  18.1s
# [CV] END max_depth=9, max_features=0.7566455605042577, min_samples_leaf=200; total time=  36.9s
# [CV] END max_depth=None, max_features=0.7495565690483859, min_samples_leaf=200; total time=  48.0s
# [CV] END max_depth=None, max_features=0.7495565690483859, min_samples_leaf=200; total time=  48.8s
# [CV] END max_depth=None, max_features=0.7495565690483859, min_samples_leaf=200; total time=  48.9s
# [CV] END max_depth=None, max_features=0.7495565690483859, min_samples_leaf=200; total time=  48.8s
# [CV] END max_depth=None, max_features=0.7495565690483859, min_samples_leaf=200; total time=  49.1s
# [CV] END max_depth=9, max_features=0.9745408858501934, min_samples_leaf=20; total time=  52.3s
# [CV] END max_depth=9, max_features=0.9745408858501934, min_samples_leaf=20; total time=  52.6s
# [CV] END max_depth=9, max_features=0.9745408858501934, min_samples_leaf=20; total time=  52.6s
# [CV] END max_depth=9, max_features=0.9745408858501934, min_samples_leaf=20; total time=  53.4s
# [CV] END max_depth=9, max_features=0.9745408858501934, min_samples_leaf=20; total time=  52.7s
# [CV] END max_depth=3, max_features=0.49540285167919307, min_samples_leaf=20; total time=   9.6s
# [CV] END max_depth=3, max_features=0.49540285167919307, min_samples_leaf=20; total time=   9.3s
# [CV] END max_depth=3, max_features=0.49540285167919307, min_samples_leaf=20; total time=   9.5s
# [CV] END max_depth=3, max_features=0.49540285167919307, min_samples_leaf=20; total time=   9.7s
# [CV] END max_depth=3, max_features=0.49540285167919307, min_samples_leaf=20; total time=   9.7s
# [CV] END max_depth=5, max_features=0.5704595464437947, min_samples_leaf=10; total time=  17.5s
# [CV] END max_depth=5, max_features=0.5704595464437947, min_samples_leaf=10; total time=  17.5s
# [CV] END max_depth=5, max_features=0.5704595464437947, min_samples_leaf=10; total time=  17.3s
# [CV] END max_depth=5, max_features=0.5704595464437947, min_samples_leaf=10; total time=  17.6s
# [CV] END max_depth=5, max_features=0.5704595464437947, min_samples_leaf=10; total time=  17.6s
# [CV] END max_depth=9, max_features=0.32436300623398745, min_samples_leaf=100; total time=  18.1s
# [CV] END max_depth=9, max_features=0.32436300623398745, min_samples_leaf=100; total time=  18.0s
# [CV] END max_depth=9, max_features=0.32436300623398745, min_samples_leaf=100; total time=  17.9s
# [CV] END max_depth=9, max_features=0.32436300623398745, min_samples_leaf=100; total time=  18.2s
# [CV] END max_depth=9, max_features=0.32436300623398745, min_samples_leaf=100; total time=  17.9s
# [CV] END max_depth=None, max_features=0.382920382968694, min_samples_leaf=50; total time=  32.0s
# [CV] END max_depth=5, max_features=0.28275510226129247, min_samples_leaf=100; total time=   9.4s
# [CV] END max_depth=5, max_features=0.28275510226129247, min_samples_leaf=100; total time=   8.9s
# [CV] END max_depth=5, max_features=0.28275510226129247, min_samples_leaf=100; total time=   9.0s
# [CV] END max_depth=None, max_features=0.382920382968694, min_samples_leaf=50; total time=  32.3s
# [CV] END max_depth=None, max_features=0.382920382968694, min_samples_leaf=50; total time=  32.0s
# [CV] END max_depth=5, max_features=0.28275510226129247, min_samples_leaf=100; total time=   8.8s
# [CV] END max_depth=None, max_features=0.382920382968694, min_samples_leaf=50; total time=  32.1s
# [CV] END max_depth=5, max_features=0.28275510226129247, min_samples_leaf=100; total time=   9.1s
# [CV] END max_depth=None, max_features=0.382920382968694, min_samples_leaf=50; total time=  32.3s
# [CV] END max_depth=3, max_features=0.661918643320414, min_samples_leaf=200; total time=  12.6s
# [CV] END max_depth=3, max_features=0.661918643320414, min_samples_leaf=200; total time=  12.4s
# [CV] END max_depth=3, max_features=0.661918643320414, min_samples_leaf=200; total time=  12.3s
# [CV] END max_depth=3, max_features=0.661918643320414, min_samples_leaf=200; total time=  12.5s
# [CV] END max_depth=3, max_features=0.661918643320414, min_samples_leaf=200; total time=  12.5s
# [CV] END max_depth=5, max_features=0.725306439735734, min_samples_leaf=50; total time=  22.4s
# [CV] END max_depth=5, max_features=0.725306439735734, min_samples_leaf=50; total time=  22.2s
# [CV] END max_depth=5, max_features=0.725306439735734, min_samples_leaf=50; total time=  22.3s
# [CV] END max_depth=5, max_features=0.725306439735734, min_samples_leaf=50; total time=  22.4s
# [CV] END max_depth=5, max_features=0.725306439735734, min_samples_leaf=50; total time=  22.5s
# [CV] END max_depth=None, max_features=0.19494483384724354, min_samples_leaf=50; total time=  17.4s
# [CV] END max_depth=None, max_features=0.19494483384724354, min_samples_leaf=50; total time=  17.4s
# [CV] END max_depth=None, max_features=0.19494483384724354, min_samples_leaf=50; total time=  17.5s
# [CV] END max_depth=None, max_features=0.19494483384724354, min_samples_leaf=50; total time=  17.5s
# [CV] END max_depth=None, max_features=0.19494483384724354, min_samples_leaf=50; total time=  17.4s
# [CV] END max_depth=7, max_features=0.2965963934951502, min_samples_leaf=50; total time=  12.3s
# [CV] END max_depth=7, max_features=0.2965963934951502, min_samples_leaf=50; total time=  12.5s
# [CV] END max_depth=7, max_features=0.2965963934951502, min_samples_leaf=50; total time=  12.5s
# [CV] END max_depth=7, max_features=0.2965963934951502, min_samples_leaf=50; total time=  12.3s
# [CV] END max_depth=7, max_features=0.2965963934951502, min_samples_leaf=50; total time=  12.2s
# [CV] END max_depth=5, max_features=0.3919105189047466, min_samples_leaf=50; total time=  12.3s
# [CV] END max_depth=5, max_features=0.3919105189047466, min_samples_leaf=50; total time=  12.6s
# [CV] END max_depth=5, max_features=0.3919105189047466, min_samples_leaf=50; total time=  12.3s
# [CV] END max_depth=5, max_features=0.3919105189047466, min_samples_leaf=50; total time=  12.6s
# [CV] END max_depth=5, max_features=0.3919105189047466, min_samples_leaf=50; total time=  12.5s
# [CV] END max_depth=None, max_features=0.30514164628774754, min_samples_leaf=200; total time=  20.1s
# [CV] END max_depth=None, max_features=0.30514164628774754, min_samples_leaf=200; total time=  20.4s
# [CV] END max_depth=None, max_features=0.30514164628774754, min_samples_leaf=200; total time=  20.1s
# [CV] END max_depth=None, max_features=0.30514164628774754, min_samples_leaf=200; total time=  20.1s
# [CV] END max_depth=None, max_features=0.30514164628774754, min_samples_leaf=200; total time=  20.5s
# [CV] END max_depth=None, max_features=0.38620312747467755, min_samples_leaf=5; total time=  47.8s
# [CV] END max_depth=None, max_features=0.38620312747467755, min_samples_leaf=5; total time=  48.2s
# [CV] END max_depth=None, max_features=0.38620312747467755, min_samples_leaf=5; total time=  48.6s
# [CV] END max_depth=None, max_features=0.38620312747467755, min_samples_leaf=5; total time=  48.7s
# [CV] END max_depth=None, max_features=0.38620312747467755, min_samples_leaf=5; total time=  49.2s
# [CV] END max_depth=5, max_features=0.10625691747807164, min_samples_leaf=20; total time=   3.8s
# [CV] END max_depth=5, max_features=0.10625691747807164, min_samples_leaf=20; total time=   3.7s
# [CV] END max_depth=5, max_features=0.10625691747807164, min_samples_leaf=20; total time=   4.1s
# [CV] END max_depth=5, max_features=0.10625691747807164, min_samples_leaf=20; total time=   3.8s
# [CV] END max_depth=5, max_features=0.10625691747807164, min_samples_leaf=20; total time=   3.9s
# [CV] END max_depth=None, max_features=0.5363469742230849, min_samples_leaf=5; total time= 1.1min
# [CV] END max_depth=None, max_features=0.5363469742230849, min_samples_leaf=5; total time= 1.1min
# [CV] END max_depth=None, max_features=0.5363469742230849, min_samples_leaf=5; total time= 1.1min
# [CV] END max_depth=None, max_features=0.5363469742230849, min_samples_leaf=5; total time= 1.1min
# [CV] END max_depth=None, max_features=0.5363469742230849, min_samples_leaf=5; total time= 1.1min
# [CV] END max_depth=None, max_features=0.8362132893302437, min_samples_leaf=5; total time= 1.6min
# [CV] END max_depth=None, max_features=0.8362132893302437, min_samples_leaf=5; total time= 1.6min
# [CV] END max_depth=5, max_features=0.34247110041866935, min_samples_leaf=20; total time=  11.3s
# [CV] END max_depth=5, max_features=0.34247110041866935, min_samples_leaf=20; total time=  11.7s
# [CV] END max_depth=None, max_features=0.8362132893302437, min_samples_leaf=5; total time= 1.7min
# [CV] END max_depth=None, max_features=0.8362132893302437, min_samples_leaf=5; total time= 1.7min
# [CV] END max_depth=5, max_features=0.34247110041866935, min_samples_leaf=20; total time=  11.4s
# [CV] END max_depth=None, max_features=0.8362132893302437, min_samples_leaf=5; total time= 1.7min
# [CV] END max_depth=5, max_features=0.34247110041866935, min_samples_leaf=20; total time=  11.5s
# [CV] END max_depth=5, max_features=0.34247110041866935, min_samples_leaf=20; total time=  11.1s
# [CV] END max_depth=None, max_features=0.4634525539522367, min_samples_leaf=200; total time=  30.4s
# [CV] END max_depth=None, max_features=0.4634525539522367, min_samples_leaf=200; total time=  30.9s
# [CV] END max_depth=None, max_features=0.3285238725409102, min_samples_leaf=50; total time=  29.6s
# [CV] END max_depth=None, max_features=0.4634525539522367, min_samples_leaf=200; total time=  31.0s
# [CV] END max_depth=None, max_features=0.3285238725409102, min_samples_leaf=50; total time=  29.4s
# [CV] END max_depth=None, max_features=0.4634525539522367, min_samples_leaf=200; total time=  31.0s
# [CV] END max_depth=None, max_features=0.3285238725409102, min_samples_leaf=50; total time=  29.5s
# [CV] END max_depth=None, max_features=0.3285238725409102, min_samples_leaf=50; total time=  29.9s
# [CV] END max_depth=None, max_features=0.3285238725409102, min_samples_leaf=50; total time=  29.9s
# [CV] END max_depth=None, max_features=0.4634525539522367, min_samples_leaf=200; total time=  31.5s
# [CV] END max_depth=3, max_features=0.7410435309319978, min_samples_leaf=100; total time=  14.2s
# [CV] END max_depth=3, max_features=0.7410435309319978, min_samples_leaf=100; total time=  14.3s
# [CV] END max_depth=3, max_features=0.7410435309319978, min_samples_leaf=100; total time=  14.4s
# [CV] END max_depth=3, max_features=0.7410435309319978, min_samples_leaf=100; total time=  14.4s
# [CV] END max_depth=3, max_features=0.7410435309319978, min_samples_leaf=100; total time=  14.6s
# [CV] END max_depth=None, max_features=0.9979664365440477, min_samples_leaf=20; total time= 1.6min
# [CV] END max_depth=None, max_features=0.9789534602493876, min_samples_leaf=50; total time= 1.4min
# [CV] END max_depth=None, max_features=0.9979664365440477, min_samples_leaf=20; total time= 1.6min
# [CV] END max_depth=None, max_features=0.9789534602493876, min_samples_leaf=50; total time= 1.4min
# [CV] END max_depth=None, max_features=0.9979664365440477, min_samples_leaf=20; total time= 1.6min
# [CV] END max_depth=None, max_features=0.9789534602493876, min_samples_leaf=50; total time= 1.4min
# [CV] END max_depth=None, max_features=0.9979664365440477, min_samples_leaf=20; total time= 1.7min
# [CV] END max_depth=None, max_features=0.9789534602493876, min_samples_leaf=50; total time= 1.5min
# [CV] END max_depth=None, max_features=0.9789534602493876, min_samples_leaf=50; total time= 1.5min
# [CV] END max_depth=None, max_features=0.9979664365440477, min_samples_leaf=20; total time= 1.7min
# [CV] END max_depth=9, max_features=0.4105641232240147, min_samples_leaf=5; total time=  22.7s
# [CV] END max_depth=9, max_features=0.4105641232240147, min_samples_leaf=5; total time=  23.0s
# [CV] END max_depth=9, max_features=0.4105641232240147, min_samples_leaf=5; total time=  22.6s
# [CV] END max_depth=9, max_features=0.4105641232240147, min_samples_leaf=5; total time=  22.9s
# [CV] END max_depth=5, max_features=0.7126349063992902, min_samples_leaf=100; total time=  21.7s
# [CV] END max_depth=5, max_features=0.7126349063992902, min_samples_leaf=100; total time=  21.7s
# [CV] END max_depth=5, max_features=0.7126349063992902, min_samples_leaf=100; total time=  21.9s
# [CV] END max_depth=9, max_features=0.4105641232240147, min_samples_leaf=5; total time=  22.7s
# [CV] END max_depth=5, max_features=0.7126349063992902, min_samples_leaf=100; total time=  21.9s
# [CV] END max_depth=5, max_features=0.7126349063992902, min_samples_leaf=100; total time=  21.5s
# [CV] END max_depth=7, max_features=0.17276799369944373, min_samples_leaf=20; total time=   7.6s
# [CV] END max_depth=7, max_features=0.17276799369944373, min_samples_leaf=20; total time=   7.9s
# [CV] END max_depth=7, max_features=0.17276799369944373, min_samples_leaf=20; total time=   7.9s
# [CV] END max_depth=7, max_features=0.17276799369944373, min_samples_leaf=20; total time=   7.9s
# [CV] END max_depth=7, max_features=0.17276799369944373, min_samples_leaf=20; total time=   7.9s
# [CV] END max_depth=7, max_features=0.5030048481157825, min_samples_leaf=200; total time=  20.1s
# [CV] END max_depth=7, max_features=0.5030048481157825, min_samples_leaf=200; total time=  20.4s
# [CV] END max_depth=7, max_features=0.5030048481157825, min_samples_leaf=200; total time=  20.4s
# [CV] END max_depth=7, max_features=0.5030048481157825, min_samples_leaf=200; total time=  20.6s
# [CV] END max_depth=7, max_features=0.5030048481157825, min_samples_leaf=200; total time=  20.4s
# [CV] END max_depth=7, max_features=0.9850808268053587, min_samples_leaf=200; total time=  42.4s
# [CV] END max_depth=7, max_features=0.9850808268053587, min_samples_leaf=200; total time=  42.4s
# [CV] END max_depth=7, max_features=0.9850808268053587, min_samples_leaf=200; total time=  42.5s
# [CV] END max_depth=7, max_features=0.9850808268053587, min_samples_leaf=200; total time=  42.3s
# [CV] END max_depth=7, max_features=0.9850808268053587, min_samples_leaf=200; total time=  41.9s
# [CV] END max_depth=None, max_features=0.7553947137506736, min_samples_leaf=100; total time=  57.4s
# [CV] END max_depth=None, max_features=0.7553947137506736, min_samples_leaf=100; total time=  56.7s
# [CV] END max_depth=None, max_features=0.7553947137506736, min_samples_leaf=100; total time=  58.1s
# [CV] END max_depth=None, max_features=0.7553947137506736, min_samples_leaf=100; total time=  57.9s
# [CV] END max_depth=None, max_features=0.7553947137506736, min_samples_leaf=100; total time=  58.5s
# [CV] END max_depth=5, max_features=0.8347886858974455, min_samples_leaf=5; total time=  25.7s
# [CV] END max_depth=5, max_features=0.8347886858974455, min_samples_leaf=5; total time=  25.6s
# [CV] END max_depth=5, max_features=0.8347886858974455, min_samples_leaf=5; total time=  25.6s
# [CV] END max_depth=5, max_features=0.8347886858974455, min_samples_leaf=5; total time=  25.6s
# [CV] END max_depth=5, max_features=0.8347886858974455, min_samples_leaf=5; total time=  25.5s
# [CV] END max_depth=None, max_features=0.3887020584745623, min_samples_leaf=200; total time=  24.9s
# [CV] END max_depth=None, max_features=0.3887020584745623, min_samples_leaf=200; total time=  24.9s
# [CV] END max_depth=None, max_features=0.3887020584745623, min_samples_leaf=200; total time=  25.2s
# [CV] END max_depth=None, max_features=0.3887020584745623, min_samples_leaf=200; total time=  25.6s
# [CV] END max_depth=None, max_features=0.3887020584745623, min_samples_leaf=200; total time=  25.6s
# [CV] END max_depth=5, max_features=0.29821694280899347, min_samples_leaf=10; total time=   9.8s
# [CV] END max_depth=5, max_features=0.29821694280899347, min_samples_leaf=10; total time=   9.9s
# [CV] END max_depth=5, max_features=0.29821694280899347, min_samples_leaf=10; total time=   9.7s
# [CV] END max_depth=5, max_features=0.29821694280899347, min_samples_leaf=10; total time=   9.8s
# [CV] END max_depth=5, max_features=0.29821694280899347, min_samples_leaf=10; total time=   9.9s
# [CV] END max_depth=5, max_features=0.8285509415257438, min_samples_leaf=50; total time=  25.7s
# [CV] END max_depth=5, max_features=0.8285509415257438, min_samples_leaf=50; total time=  25.8s
# [CV] END max_depth=5, max_features=0.8285509415257438, min_samples_leaf=50; total time=  25.9s
# [CV] END max_depth=5, max_features=0.8285509415257438, min_samples_leaf=50; total time=  25.9s
# [CV] END max_depth=5, max_features=0.8285509415257438, min_samples_leaf=50; total time=  25.9s
# [CV] END max_depth=9, max_features=0.8725229243323479, min_samples_leaf=50; total time=  47.4s
# [CV] END max_depth=9, max_features=0.8725229243323479, min_samples_leaf=50; total time=  47.2s
# [CV] END max_depth=9, max_features=0.8725229243323479, min_samples_leaf=50; total time=  46.7s
# [CV] END max_depth=9, max_features=0.8725229243323479, min_samples_leaf=50; total time=  47.4s
# [CV] END max_depth=9, max_features=0.8725229243323479, min_samples_leaf=50; total time=  47.3s
# [CV] END max_depth=7, max_features=0.9464709380406436, min_samples_leaf=10; total time=  40.3s
# [CV] END max_depth=7, max_features=0.9464709380406436, min_samples_leaf=10; total time=  40.5s
# [CV] END max_depth=7, max_features=0.9464709380406436, min_samples_leaf=10; total time=  40.1s
# [CV] END max_depth=7, max_features=0.9464709380406436, min_samples_leaf=10; total time=  40.1s
# [CV] END max_depth=7, max_features=0.9464709380406436, min_samples_leaf=10; total time=  40.4s
# [CV] END max_depth=None, max_features=0.28816445866394236, min_samples_leaf=200; total time=  19.5s
# [CV] END max_depth=None, max_features=0.28816445866394236, min_samples_leaf=200; total time=  19.6s
# [CV] END max_depth=None, max_features=0.28816445866394236, min_samples_leaf=200; total time=  19.7s
# [CV] END max_depth=None, max_features=0.28816445866394236, min_samples_leaf=200; total time=  19.7s
# [CV] END max_depth=None, max_features=0.28816445866394236, min_samples_leaf=200; total time=  19.8s
# [CV] END max_depth=3, max_features=0.33214746494364006, min_samples_leaf=50; total time=   6.4s
# [CV] END max_depth=3, max_features=0.33214746494364006, min_samples_leaf=50; total time=   6.6s
# [CV] END max_depth=3, max_features=0.33214746494364006, min_samples_leaf=50; total time=   6.4s
# [CV] END max_depth=3, max_features=0.33214746494364006, min_samples_leaf=50; total time=   6.4s
# [CV] END max_depth=3, max_features=0.33214746494364006, min_samples_leaf=50; total time=   6.5s
# [CV] END max_depth=3, max_features=0.983951508996492, min_samples_leaf=50; total time=  18.9s
# [CV] END max_depth=3, max_features=0.983951508996492, min_samples_leaf=50; total time=  18.8s
# [CV] END max_depth=3, max_features=0.983951508996492, min_samples_leaf=50; total time=  18.6s
# [CV] END max_depth=3, max_features=0.983951508996492, min_samples_leaf=50; total time=  18.6s
# [CV] END max_depth=3, max_features=0.983951508996492, min_samples_leaf=50; total time=  18.6s
# [CV] END max_depth=None, max_features=0.7081211053353527, min_samples_leaf=5; total time= 1.4min
# [CV] END max_depth=None, max_features=0.7081211053353527, min_samples_leaf=5; total time= 1.4min
# [CV] END max_depth=None, max_features=0.7081211053353527, min_samples_leaf=5; total time= 1.4min
# [CV] END max_depth=None, max_features=0.7081211053353527, min_samples_leaf=5; total time= 1.4min
# [CV] END max_depth=None, max_features=0.7081211053353527, min_samples_leaf=5; total time= 1.4min
# [CV] END max_depth=7, max_features=0.3347462573473681, min_samples_leaf=5; total time=  14.2s
# [CV] END max_depth=7, max_features=0.3347462573473681, min_samples_leaf=5; total time=  14.3s
# [CV] END max_depth=7, max_features=0.3347462573473681, min_samples_leaf=5; total time=  14.3s
# [CV] END max_depth=7, max_features=0.3347462573473681, min_samples_leaf=5; total time=  14.4s
# [CV] END max_depth=7, max_features=0.3347462573473681, min_samples_leaf=5; total time=  14.6s
# [CV] END max_depth=7, max_features=0.6024641082463879, min_samples_leaf=20; total time=  27.0s
# [CV] END max_depth=7, max_features=0.6024641082463879, min_samples_leaf=20; total time=  27.2s
# [CV] END max_depth=7, max_features=0.6024641082463879, min_samples_leaf=20; total time=  27.6s
# [CV] END max_depth=7, max_features=0.6024641082463879, min_samples_leaf=20; total time=  27.0s
# [CV] END max_depth=7, max_features=0.6024641082463879, min_samples_leaf=20; total time=  27.6s
# [CV] END max_depth=None, max_features=0.3509842173329637, min_samples_leaf=20; total time=  35.4s
# [CV] END max_depth=None, max_features=0.3509842173329637, min_samples_leaf=20; total time=  36.1s
# [CV] END max_depth=None, max_features=0.3509842173329637, min_samples_leaf=20; total time=  35.8s
# [CV] END max_depth=None, max_features=0.3509842173329637, min_samples_leaf=20; total time=  35.9s
# [CV] END max_depth=None, max_features=0.3509842173329637, min_samples_leaf=20; total time=  35.8s
# [CV] END max_depth=5, max_features=0.8706918626902832, min_samples_leaf=200; total time=  27.4s
# [CV] END max_depth=5, max_features=0.8706918626902832, min_samples_leaf=200; total time=  27.6s
# [CV] END max_depth=5, max_features=0.8706918626902832, min_samples_leaf=200; total time=  27.0s
# [CV] END max_depth=5, max_features=0.8706918626902832, min_samples_leaf=200; total time=  27.6s
# [CV] END max_depth=5, max_features=0.8706918626902832, min_samples_leaf=200; total time=  27.4s
# [CV] END max_depth=None, max_features=0.2454658426851524, min_samples_leaf=200; total time=  17.0s
# [CV] END max_depth=None, max_features=0.2454658426851524, min_samples_leaf=200; total time=  16.9s
# [CV] END max_depth=None, max_features=0.2454658426851524, min_samples_leaf=200; total time=  17.0s
# [CV] END max_depth=None, max_features=0.2454658426851524, min_samples_leaf=200; total time=  16.9s
# [CV] END max_depth=None, max_features=0.2454658426851524, min_samples_leaf=200; total time=  17.2s
# [CV] END max_depth=7, max_features=0.6226179592928092, min_samples_leaf=200; total time=  25.5s
# [CV] END max_depth=7, max_features=0.6226179592928092, min_samples_leaf=200; total time=  25.5s
# [CV] END max_depth=7, max_features=0.6226179592928092, min_samples_leaf=200; total time=  25.4s
# [CV] END max_depth=7, max_features=0.6226179592928092, min_samples_leaf=200; total time=  25.8s
# [CV] END max_depth=7, max_features=0.6226179592928092, min_samples_leaf=200; total time=  25.5s
# [CV] END max_depth=None, max_features=0.677828481538859, min_samples_leaf=20; total time= 1.1min
# [CV] END max_depth=None, max_features=0.677828481538859, min_samples_leaf=20; total time= 1.1min
# [CV] END max_depth=None, max_features=0.677828481538859, min_samples_leaf=20; total time= 1.1min
# [CV] END max_depth=None, max_features=0.677828481538859, min_samples_leaf=20; total time= 1.1min
# [CV] END max_depth=None, max_features=0.677828481538859, min_samples_leaf=20; total time= 1.1min
# [CV] END max_depth=3, max_features=0.2447272462757488, min_samples_leaf=10; total time=   4.8s
# [CV] END max_depth=3, max_features=0.2447272462757488, min_samples_leaf=10; total time=   5.1s
# [CV] END max_depth=3, max_features=0.2447272462757488, min_samples_leaf=10; total time=   4.9s
# [CV] END max_depth=3, max_features=0.2447272462757488, min_samples_leaf=10; total time=   5.3s
# [CV] END max_depth=3, max_features=0.2447272462757488, min_samples_leaf=10; total time=   5.2s
# [CV] END max_depth=3, max_features=0.7227056779234239, min_samples_leaf=100; total time=  13.5s
# [CV] END max_depth=3, max_features=0.7227056779234239, min_samples_leaf=100; total time=  13.5s
# [CV] END max_depth=3, max_features=0.7227056779234239, min_samples_leaf=100; total time=  13.3s
# [CV] END max_depth=3, max_features=0.7227056779234239, min_samples_leaf=100; total time=  13.4s
# [CV] END max_depth=3, max_features=0.7227056779234239, min_samples_leaf=100; total time=  13.5s
# [CV] END max_depth=None, max_features=0.6971515921972502, min_samples_leaf=100; total time=  50.8s
# [CV] END max_depth=None, max_features=0.6971515921972502, min_samples_leaf=100; total time=  50.9s
# [CV] END max_depth=None, max_features=0.6971515921972502, min_samples_leaf=100; total time=  51.9s
# [CV] END max_depth=None, max_features=0.6971515921972502, min_samples_leaf=100; total time=  51.5s
# [CV] END max_depth=None, max_features=0.6971515921972502, min_samples_leaf=100; total time=  51.5s
# [CV] END max_depth=None, max_features=0.2583327274096109, min_samples_leaf=50; total time=  23.6s
# [CV] END max_depth=None, max_features=0.2583327274096109, min_samples_leaf=50; total time=  23.1s
# [CV] END max_depth=None, max_features=0.2583327274096109, min_samples_leaf=50; total time=  23.6s
# [CV] END max_depth=None, max_features=0.2583327274096109, min_samples_leaf=50; total time=  23.6s
# [CV] END max_depth=None, max_features=0.2583327274096109, min_samples_leaf=50; total time=  23.5s
# [CV] END max_depth=5, max_features=0.691851603070309, min_samples_leaf=5; total time=  22.3s
# [CV] END max_depth=5, max_features=0.691851603070309, min_samples_leaf=5; total time=  22.4s
# [CV] END max_depth=5, max_features=0.691851603070309, min_samples_leaf=5; total time=  22.0s
# [CV] END max_depth=5, max_features=0.691851603070309, min_samples_leaf=5; total time=  22.2s
# [CV] END max_depth=5, max_features=0.691851603070309, min_samples_leaf=5; total time=  22.4s
# [CV] END max_depth=None, max_features=0.5445043436650912, min_samples_leaf=50; total time=  46.8s
# [CV] END max_depth=None, max_features=0.5445043436650912, min_samples_leaf=50; total time=  48.3s
# [CV] END max_depth=7, max_features=0.557932669154884, min_samples_leaf=200; total time=  24.6s
# [CV] END max_depth=None, max_features=0.5445043436650912, min_samples_leaf=50; total time=  48.4s
# [CV] END max_depth=7, max_features=0.557932669154884, min_samples_leaf=200; total time=  24.8s
# [CV] END max_depth=None, max_features=0.5445043436650912, min_samples_leaf=50; total time=  48.4s
# [CV] END max_depth=None, max_features=0.5445043436650912, min_samples_leaf=50; total time=  47.7s
# [CV] END max_depth=7, max_features=0.557932669154884, min_samples_leaf=200; total time=  24.8s
# [CV] END max_depth=7, max_features=0.557932669154884, min_samples_leaf=200; total time=  24.2s
# [CV] END max_depth=7, max_features=0.557932669154884, min_samples_leaf=200; total time=  24.7s
# [CV] END max_depth=5, max_features=0.8153301731874836, min_samples_leaf=200; total time=  25.8s
# [CV] END max_depth=5, max_features=0.8153301731874836, min_samples_leaf=200; total time=  25.9s
# [CV] END max_depth=5, max_features=0.8153301731874836, min_samples_leaf=200; total time=  25.8s
# [CV] END max_depth=9, max_features=0.5380679376635096, min_samples_leaf=20; total time=  31.2s
# [CV] END max_depth=9, max_features=0.5380679376635096, min_samples_leaf=20; total time=  30.7s
# [CV] END max_depth=5, max_features=0.8153301731874836, min_samples_leaf=200; total time=  25.3s
# [CV] END max_depth=5, max_features=0.8153301731874836, min_samples_leaf=200; total time=  25.5s
# [CV] END max_depth=9, max_features=0.5380679376635096, min_samples_leaf=20; total time=  30.8s
# [CV] END max_depth=9, max_features=0.5380679376635096, min_samples_leaf=20; total time=  30.8s
# [CV] END max_depth=9, max_features=0.5380679376635096, min_samples_leaf=20; total time=  31.0s
# [CV] END max_depth=9, max_features=0.30716674141739975, min_samples_leaf=20; total time=  17.8s
# [CV] END max_depth=9, max_features=0.30716674141739975, min_samples_leaf=20; total time=  17.8s
# [CV] END max_depth=9, max_features=0.30716674141739975, min_samples_leaf=20; total time=  17.4s
# [CV] END max_depth=9, max_features=0.30716674141739975, min_samples_leaf=20; total time=  17.8s
# [CV] END max_depth=9, max_features=0.30716674141739975, min_samples_leaf=20; total time=  17.9s
# [CV] END max_depth=7, max_features=0.12188436978830847, min_samples_leaf=5; total time=   5.3s
# [CV] END max_depth=7, max_features=0.12188436978830847, min_samples_leaf=5; total time=   5.5s
# [CV] END max_depth=7, max_features=0.12188436978830847, min_samples_leaf=5; total time=   5.3s
# [CV] END max_depth=7, max_features=0.12188436978830847, min_samples_leaf=5; total time=   5.3s
# [CV] END max_depth=7, max_features=0.12188436978830847, min_samples_leaf=5; total time=   5.6s
# [CV] END max_depth=None, max_features=0.6192134961637232, min_samples_leaf=5; total time= 1.2min
# [CV] END max_depth=None, max_features=0.6192134961637232, min_samples_leaf=5; total time= 1.2min
# [CV] END max_depth=None, max_features=0.6192134961637232, min_samples_leaf=5; total time= 1.2min
# [CV] END max_depth=None, max_features=0.6192134961637232, min_samples_leaf=5; total time= 1.2min
# [CV] END max_depth=None, max_features=0.6192134961637232, min_samples_leaf=5; total time= 1.2min
# [CV] END max_depth=None, max_features=0.9950954597176069, min_samples_leaf=200; total time= 1.0min
# [CV] END max_depth=None, max_features=0.9950954597176069, min_samples_leaf=200; total time= 1.1min
# [CV] END max_depth=9, max_features=0.3516043076170827, min_samples_leaf=200; total time=  18.3s
# [CV] END max_depth=9, max_features=0.3516043076170827, min_samples_leaf=200; total time=  18.1s
# [CV] END max_depth=None, max_features=0.9950954597176069, min_samples_leaf=200; total time= 1.1min
# [CV] END max_depth=None, max_features=0.9950954597176069, min_samples_leaf=200; total time= 1.1min
# [CV] END max_depth=None, max_features=0.9950954597176069, min_samples_leaf=200; total time= 1.1min
# [CV] END max_depth=9, max_features=0.3516043076170827, min_samples_leaf=200; total time=  17.9s
# [CV] END max_depth=9, max_features=0.3516043076170827, min_samples_leaf=200; total time=  17.7s
# [CV] END max_depth=9, max_features=0.3516043076170827, min_samples_leaf=200; total time=  18.1s
# [CV] END max_depth=5, max_features=0.7729468965076726, min_samples_leaf=100; total time=  23.9s
# [CV] END max_depth=5, max_features=0.7729468965076726, min_samples_leaf=100; total time=  23.7s
# [CV] END max_depth=5, max_features=0.7729468965076726, min_samples_leaf=100; total time=  24.1s
# [CV] END max_depth=5, max_features=0.7729468965076726, min_samples_leaf=100; total time=  24.0s
# [CV] END max_depth=5, max_features=0.7729468965076726, min_samples_leaf=100; total time=  24.6s
# [CV] END max_depth=9, max_features=0.4853657334855829, min_samples_leaf=100; total time=  25.6s
# [CV] END max_depth=9, max_features=0.4853657334855829, min_samples_leaf=100; total time=  25.7s
# [CV] END max_depth=9, max_features=0.4853657334855829, min_samples_leaf=100; total time=  26.0s
# [CV] END max_depth=9, max_features=0.4853657334855829, min_samples_leaf=100; total time=  25.8s
# [CV] END max_depth=9, max_features=0.4853657334855829, min_samples_leaf=100; total time=  25.8s
# [CV] END max_depth=5, max_features=0.9822984253444411, min_samples_leaf=50; total time=  30.4s
# [CV] END max_depth=9, max_features=0.4465879557417327, min_samples_leaf=5; total time=  25.0s
# [CV] END max_depth=9, max_features=0.4465879557417327, min_samples_leaf=5; total time=  25.2s
# [CV] END max_depth=9, max_features=0.4465879557417327, min_samples_leaf=5; total time=  25.0s
# [CV] END max_depth=5, max_features=0.9822984253444411, min_samples_leaf=50; total time=  31.1s
# [CV] END max_depth=9, max_features=0.4465879557417327, min_samples_leaf=5; total time=  25.4s
# [CV] END max_depth=9, max_features=0.4465879557417327, min_samples_leaf=5; total time=  25.1s
# [CV] END max_depth=5, max_features=0.9822984253444411, min_samples_leaf=50; total time=  30.8s
# [CV] END max_depth=5, max_features=0.9822984253444411, min_samples_leaf=50; total time=  30.7s
# [CV] END max_depth=5, max_features=0.9822984253444411, min_samples_leaf=50; total time=  31.3s
# [CV] END max_depth=5, max_features=0.2525434720174833, min_samples_leaf=5; total time=   8.1s
# [CV] END max_depth=5, max_features=0.2525434720174833, min_samples_leaf=5; total time=   8.3s
# [CV] END max_depth=5, max_features=0.2525434720174833, min_samples_leaf=5; total time=   8.2s
# ...
# [CV] END max_depth=9, max_features=0.9378361951185633, min_samples_leaf=10; total time=  51.1s
# [CV] END max_depth=9, max_features=0.9378361951185633, min_samples_leaf=10; total time=  51.1s
# [CV] END max_depth=9, max_features=0.9378361951185633, min_samples_leaf=10; total time=  50.0s
# [CV] END max_depth=9, max_features=0.9378361951185633, min_samples_leaf=10; total time=  50.1s
# [CV] END max_depth=5, max_features=0.7352483354908251, min_samples_leaf=50; total time=  21.9s
# [CV] END max_depth=5, max_features=0.7352483354908251, min_samples_leaf=50; total time=  21.5s
# [CV] END max_depth=5, max_features=0.7352483354908251, min_samples_leaf=50; total time=  21.7s
# [CV] END max_depth=9, max_features=0.9378361951185633, min_samples_leaf=10; total time=  50.8s
# [CV] END max_depth=5, max_features=0.7352483354908251, min_samples_leaf=50; total time=  21.8s
# [CV] END max_depth=5, max_features=0.7352483354908251, min_samples_leaf=50; total time=  21.2s
# [CV] END max_depth=None, max_features=0.1910104085105112, min_samples_leaf=200; total time=  11.7s
# [CV] END max_depth=None, max_features=0.1910104085105112, min_samples_leaf=200; total time=  11.9s
# [CV] END max_depth=None, max_features=0.1910104085105112, min_samples_leaf=200; total time=  11.9s
# [CV] END max_depth=None, max_features=0.1910104085105112, min_samples_leaf=200; total time=  12.1s
# [CV] END max_depth=None, max_features=0.1910104085105112, min_samples_leaf=200; total time=  12.2s
# [CV] END max_depth=9, max_features=0.3003187758139275, min_samples_leaf=5; total time=  18.3s
# [CV] END max_depth=9, max_features=0.3003187758139275, min_samples_leaf=5; total time=  18.7s
# [CV] END max_depth=9, max_features=0.3003187758139275, min_samples_leaf=5; total time=  18.9s
# [CV] END max_depth=9, max_features=0.3003187758139275, min_samples_leaf=5; total time=  18.9s
# [CV] END max_depth=9, max_features=0.3003187758139275, min_samples_leaf=5; total time=  18.6s
# [CV] END max_depth=3, max_features=0.9027072178990989, min_samples_leaf=10; total time=  16.9s
# [CV] END max_depth=3, max_features=0.9027072178990989, min_samples_leaf=10; total time=  16.6s
# [CV] END max_depth=3, max_features=0.9027072178990989, min_samples_leaf=10; total time=  16.7s
# [CV] END max_depth=3, max_features=0.9027072178990989, min_samples_leaf=10; total time=  17.0s
# [CV] END max_depth=3, max_features=0.9027072178990989, min_samples_leaf=10; total time=  16.8s
# [CV] END max_depth=None, max_features=0.785359568545725, min_samples_leaf=50; total time= 1.1min
# [CV] END max_depth=None, max_features=0.785359568545725, min_samples_leaf=50; total time= 1.1min
# [CV] END max_depth=None, max_features=0.785359568545725, min_samples_leaf=50; total time= 1.1min
# [CV] END max_depth=None, max_features=0.785359568545725, min_samples_leaf=50; total time= 1.1min
# [CV] END max_depth=None, max_features=0.785359568545725, min_samples_leaf=50; total time= 1.1min
# [CV] END max_depth=9, max_features=0.5619935518231536, min_samples_leaf=200; total time=  29.3s
# [CV] END max_depth=9, max_features=0.5619935518231536, min_samples_leaf=200; total time=  29.2s
# [CV] END max_depth=9, max_features=0.5619935518231536, min_samples_leaf=200; total time=  29.2s
# [CV] END max_depth=9, max_features=0.5619935518231536, min_samples_leaf=200; total time=  29.1s
# [CV] END max_depth=9, max_features=0.5619935518231536, min_samples_leaf=200; total time=  29.6s
# [CV] END max_depth=5, max_features=0.6231748755041041, min_samples_leaf=100; total time=  20.7s
# [CV] END max_depth=5, max_features=0.6231748755041041, min_samples_leaf=100; total time=  20.4s
# [CV] END max_depth=5, max_features=0.6231748755041041, min_samples_leaf=100; total time=  20.5s
# [CV] END max_depth=5, max_features=0.6231748755041041, min_samples_leaf=100; total time=  20.4s
# [CV] END max_depth=5, max_features=0.6231748755041041, min_samples_leaf=100; total time=  20.4s
# [CV] END max_depth=None, max_features=0.6326998649391559, min_samples_leaf=50; total time=  55.8s
# [CV] END max_depth=None, max_features=0.6326998649391559, min_samples_leaf=50; total time=  55.0s
# [CV] END max_depth=None, max_features=0.6326998649391559, min_samples_leaf=50; total time=  55.7s
# [CV] END max_depth=None, max_features=0.6326998649391559, min_samples_leaf=50; total time=  56.0s
# [CV] END max_depth=None, max_features=0.6326998649391559, min_samples_leaf=50; total time=  55.8s
# [CV] END max_depth=7, max_features=0.1751506450288019, min_samples_leaf=100; total time=   8.2s
# [CV] END max_depth=7, max_features=0.1751506450288019, min_samples_leaf=100; total time=   8.2s
# [CV] END max_depth=7, max_features=0.1751506450288019, min_samples_leaf=100; total time=   8.1s
# [CV] END max_depth=7, max_features=0.1751506450288019, min_samples_leaf=100; total time=   8.5s
# [CV] END max_depth=7, max_features=0.1751506450288019, min_samples_leaf=100; total time=   8.1s
# [CV] END max_depth=7, max_features=0.6025638247622246, min_samples_leaf=20; total time=  26.8s
# [CV] END max_depth=7, max_features=0.6025638247622246, min_samples_leaf=20; total time=  26.9s
# [CV] END max_depth=7, max_features=0.6025638247622246, min_samples_leaf=20; total time=  27.0s
# [CV] END max_depth=7, max_features=0.6025638247622246, min_samples_leaf=20; total time=  26.7s
# [CV] END max_depth=7, max_features=0.6025638247622246, min_samples_leaf=20; total time=  27.3s
# [CV] END max_depth=None, max_features=0.8923239717745751, min_samples_leaf=5; total time= 1.7min
# [CV] END max_depth=None, max_features=0.8923239717745751, min_samples_leaf=5; total time= 1.7min
# [CV] END max_depth=None, max_features=0.8923239717745751, min_samples_leaf=5; total time= 1.7min
# [CV] END max_depth=None, max_features=0.8923239717745751, min_samples_leaf=5; total time= 1.7min
# [CV] END max_depth=None, max_features=0.8923239717745751, min_samples_leaf=5; total time= 1.8min
# [CV] END max_depth=3, max_features=0.9157189465852624, min_samples_leaf=200; total time=  17.0s
# [CV] END max_depth=3, max_features=0.9157189465852624, min_samples_leaf=200; total time=  16.7s
# [CV] END max_depth=5, max_features=0.32831395648582484, min_samples_leaf=10; total time=  10.7s
# [CV] END max_depth=5, max_features=0.32831395648582484, min_samples_leaf=10; total time=  11.0s
# [CV] END max_depth=5, max_features=0.32831395648582484, min_samples_leaf=10; total time=  11.0s
# [CV] END max_depth=3, max_features=0.9157189465852624, min_samples_leaf=200; total time=  16.9s
# [CV] END max_depth=5, max_features=0.32831395648582484, min_samples_leaf=10; total time=  10.8s
# [CV] END max_depth=3, max_features=0.9157189465852624, min_samples_leaf=200; total time=  16.9s
# [CV] END max_depth=5, max_features=0.32831395648582484, min_samples_leaf=10; total time=  11.0s
# [CV] END max_depth=3, max_features=0.9157189465852624, min_samples_leaf=200; total time=  16.5s
# [CV] END max_depth=7, max_features=0.6143257226845096, min_samples_leaf=50; total time=  26.1s
# [CV] END max_depth=7, max_features=0.6143257226845096, min_samples_leaf=50; total time=  26.0s
# [CV] END max_depth=7, max_features=0.6143257226845096, min_samples_leaf=50; total time=  26.0s
# [CV] END max_depth=7, max_features=0.6143257226845096, min_samples_leaf=50; total time=  26.4s
# [CV] END max_depth=7, max_features=0.6143257226845096, min_samples_leaf=50; total time=  26.2s
# [CV] END max_depth=7, max_features=0.7904753677977145, min_samples_leaf=5; total time=  34.1s
# [CV] END max_depth=7, max_features=0.7904753677977145, min_samples_leaf=5; total time=  34.7s
# [CV] END max_depth=7, max_features=0.7904753677977145, min_samples_leaf=5; total time=  34.4s
# [CV] END max_depth=7, max_features=0.7904753677977145, min_samples_leaf=5; total time=  34.6s
# [CV] END max_depth=7, max_features=0.7904753677977145, min_samples_leaf=5; total time=  34.7s
# [CV] END max_depth=None, max_features=0.7129354843872181, min_samples_leaf=50; total time=  59.5s
# [CV] END max_depth=None, max_features=0.7129354843872181, min_samples_leaf=50; total time=  59.6s
# [CV] END max_depth=None, max_features=0.7129354843872181, min_samples_leaf=50; total time= 1.0min
# [CV] END max_depth=None, max_features=0.7129354843872181, min_samples_leaf=50; total time= 1.0min
# [CV] END max_depth=None, max_features=0.7129354843872181, min_samples_leaf=50; total time= 1.0min
# [CV] END max_depth=None, max_features=0.43738352157133364, min_samples_leaf=5; total time=  51.7s
# [CV] END max_depth=None, max_features=0.43738352157133364, min_samples_leaf=5; total time=  52.4s
# [CV] END max_depth=None, max_features=0.43738352157133364, min_samples_leaf=5; total time=  52.4s
# [CV] END max_depth=None, max_features=0.43738352157133364, min_samples_leaf=5; total time=  52.7s
# [CV] END max_depth=None, max_features=0.43738352157133364, min_samples_leaf=5; total time=  52.8s
# [CV] END max_depth=None, max_features=0.8817392153705143, min_samples_leaf=200; total time=  56.9s
# [CV] END max_depth=None, max_features=0.8817392153705143, min_samples_leaf=200; total time=  56.8s
# [CV] END max_depth=9, max_features=0.9669002854965502, min_samples_leaf=50; total time=  53.4s
# [CV] END max_depth=None, max_features=0.8817392153705143, min_samples_leaf=200; total time=  57.6s
# [CV] END max_depth=9, max_features=0.9669002854965502, min_samples_leaf=50; total time=  53.8s
# [CV] END max_depth=9, max_features=0.9669002854965502, min_samples_leaf=50; total time=  53.9s
# [CV] END max_depth=9, max_features=0.9669002854965502, min_samples_leaf=50; total time=  53.1s
# [CV] END max_depth=9, max_features=0.9669002854965502, min_samples_leaf=50; total time=  53.4s
# [CV] END max_depth=None, max_features=0.8817392153705143, min_samples_leaf=200; total time=  58.1s
# [CV] END max_depth=None, max_features=0.8817392153705143, min_samples_leaf=200; total time=  58.0s
# [CV] END max_depth=9, max_features=0.1390607049683555, min_samples_leaf=100; total time=   7.2s
# [CV] END max_depth=9, max_features=0.1390607049683555, min_samples_leaf=100; total time=   7.4s
# [CV] END max_depth=9, max_features=0.1390607049683555, min_samples_leaf=100; total time=   7.3s
# [CV] END max_depth=9, max_features=0.1390607049683555, min_samples_leaf=100; total time=   7.4s
# [CV] END max_depth=9, max_features=0.1390607049683555, min_samples_leaf=100; total time=   7.4s
# [CV] END max_depth=5, max_features=0.9272041437507935, min_samples_leaf=50; total time=  27.6s
# [CV] END max_depth=5, max_features=0.9272041437507935, min_samples_leaf=50; total time=  27.6s
# [CV] END max_depth=5, max_features=0.9272041437507935, min_samples_leaf=50; total time=  27.6s
# [CV] END max_depth=5, max_features=0.9272041437507935, min_samples_leaf=50; total time=  27.6s
# [CV] END max_depth=5, max_features=0.9272041437507935, min_samples_leaf=50; total time=  27.8s
# [CV] END max_depth=9, max_features=0.9728909440368751, min_samples_leaf=100; total time=  47.5s
# [CV] END max_depth=9, max_features=0.9728909440368751, min_samples_leaf=100; total time=  47.5s
# [CV] END max_depth=9, max_features=0.9728909440368751, min_samples_leaf=100; total time=  48.0s
# [CV] END max_depth=9, max_features=0.9728909440368751, min_samples_leaf=100; total time=  47.6s
# [CV] END max_depth=9, max_features=0.9728909440368751, min_samples_leaf=100; total time=  48.3s
# [CV] END max_depth=3, max_features=0.24959388871832763, min_samples_leaf=5; total time=   4.5s
# [CV] END max_depth=3, max_features=0.24959388871832763, min_samples_leaf=5; total time=   4.5s
# [CV] END max_depth=3, max_features=0.24959388871832763, min_samples_leaf=5; total time=   4.5s
# [CV] END max_depth=3, max_features=0.24959388871832763, min_samples_leaf=5; total time=   4.5s
# [CV] END max_depth=3, max_features=0.24959388871832763, min_samples_leaf=5; total time=   4.8s
# [CV] END max_depth=5, max_features=0.7258700107959828, min_samples_leaf=5; total time=  21.5s
# [CV] END max_depth=5, max_features=0.7258700107959828, min_samples_leaf=5; total time=  21.5s
# [CV] END max_depth=5, max_features=0.7258700107959828, min_samples_leaf=5; total time=  21.8s
# [CV] END max_depth=5, max_features=0.7258700107959828, min_samples_leaf=5; total time=  21.5s
# [CV] END max_depth=5, max_features=0.7258700107959828, min_samples_leaf=5; total time=  21.7s
# [CV] END max_depth=5, max_features=0.9110422094418901, min_samples_leaf=5; total time=  27.1s
# [CV] END max_depth=5, max_features=0.9110422094418901, min_samples_leaf=5; total time=  26.7s
# [CV] END max_depth=5, max_features=0.9110422094418901, min_samples_leaf=5; total time=  26.9s
# [CV] END max_depth=5, max_features=0.9110422094418901, min_samples_leaf=5; total time=  27.0s
# [CV] END max_depth=5, max_features=0.9110422094418901, min_samples_leaf=5; total time=  27.3s
# [CV] END max_depth=None, max_features=0.6648022720756571, min_samples_leaf=200; total time=  41.2s
# [CV] END max_depth=None, max_features=0.6648022720756571, min_samples_leaf=200; total time=  40.9s
# [CV] END max_depth=None, max_features=0.6648022720756571, min_samples_leaf=200; total time=  41.1s
# [CV] END max_depth=None, max_features=0.6648022720756571, min_samples_leaf=200; total time=  41.6s
# [CV] END max_depth=5, max_features=0.35286687063300726, min_samples_leaf=200; total time=  10.2s
# [CV] END max_depth=5, max_features=0.35286687063300726, min_samples_leaf=200; total time=  10.3s
# [CV] END max_depth=None, max_features=0.6648022720756571, min_samples_leaf=200; total time=  41.0s
# [CV] END max_depth=5, max_features=0.35286687063300726, min_samples_leaf=200; total time=  10.2s
# [CV] END max_depth=5, max_features=0.35286687063300726, min_samples_leaf=200; total time=  10.2s
# [CV] END max_depth=5, max_features=0.35286687063300726, min_samples_leaf=200; total time=  10.4s
# [CV] END max_depth=3, max_features=0.2693090437513852, min_samples_leaf=10; total time=   5.1s
# [CV] END max_depth=3, max_features=0.2693090437513852, min_samples_leaf=10; total time=   5.2s
# [CV] END max_depth=7, max_features=0.19608045934229595, min_samples_leaf=100; total time=   8.2s
# [CV] END max_depth=3, max_features=0.2693090437513852, min_samples_leaf=10; total time=   5.1s
# [CV] END max_depth=7, max_features=0.19608045934229595, min_samples_leaf=100; total time=   8.2s
# [CV] END max_depth=3, max_features=0.2693090437513852, min_samples_leaf=10; total time=   5.1s
# [CV] END max_depth=7, max_features=0.19608045934229595, min_samples_leaf=100; total time=   8.2s
# [CV] END max_depth=7, max_features=0.19608045934229595, min_samples_leaf=100; total time=   8.5s
# [CV] END max_depth=7, max_features=0.19608045934229595, min_samples_leaf=100; total time=   8.4s
# [CV] END max_depth=3, max_features=0.2693090437513852, min_samples_leaf=10; total time=   5.2s
# [CV] END max_depth=3, max_features=0.3064552711344547, min_samples_leaf=50; total time=   5.7s
# [CV] END max_depth=3, max_features=0.3064552711344547, min_samples_leaf=50; total time=   5.7s
# [CV] END max_depth=3, max_features=0.3064552711344547, min_samples_leaf=50; total time=   5.8s
# [CV] END max_depth=3, max_features=0.3064552711344547, min_samples_leaf=50; total time=   5.9s
# [CV] END max_depth=3, max_features=0.3064552711344547, min_samples_leaf=50; total time=   5.9s
# [CV] END max_depth=7, max_features=0.42431058568474145, min_samples_leaf=50; total time=  17.9s
# [CV] END max_depth=7, max_features=0.42431058568474145, min_samples_leaf=50; total time=  17.8s
# [CV] END max_depth=7, max_features=0.42431058568474145, min_samples_leaf=50; total time=  18.0s
# [CV] END max_depth=7, max_features=0.42431058568474145, min_samples_leaf=50; total time=  17.6s
# [CV] END max_depth=7, max_features=0.42431058568474145, min_samples_leaf=50; total time=  17.1s
# [CV] END max_depth=5, max_features=0.7283455426177706, min_samples_leaf=5; total time=  18.7s
# [CV] END max_depth=5, max_features=0.7283455426177706, min_samples_leaf=5; total time=  18.5s
# [CV] END max_depth=5, max_features=0.7283455426177706, min_samples_leaf=5; total time=  18.4s
# [CV] END max_depth=5, max_features=0.7283455426177706, min_samples_leaf=5; total time=  18.3s
# [CV] END max_depth=5, max_features=0.7283455426177706, min_samples_leaf=5; total time=  18.0s
#
# Best params: {'max_depth': None, 'max_features': np.float64(0.5363469742230849), 'min_samples_leaf': 5}
# Best CV score (neg MSE): -225.1597249845484

# %%
# 6) Evaluate the best model on the test set
best_forest = random_search.best_estimator_

y_pred_test = best_forest.predict(X_test_scaled)

mae = mean_absolute_error(y_test, y_pred_test)
r2  = r2_score(y_test, y_pred_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))


print("\n=== Test set performance of best random-search tree ===")
print(f"Mean Absolute Error: {mae:.4f}")
print(f"  RMSE: {rmse:.4f}")
print(f"R²:                  {r2:.4f}")
# Out:
# === Test set performance of best random-search tree ===
# Mean Absolute Error: 11.3504
#   RMSE: 14.7216
# R²:                  0.3351
