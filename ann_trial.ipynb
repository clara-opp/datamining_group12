# %%
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import matplotlib.pyplot as plt
from utils_io import load_step, save_step

X_train = load_step("step3_X_train")
X_test = load_step("step3_X_test")
y_train = load_step("step3_y_train")
y_test = load_step("step3_y_test")

X_train_scaled = load_step("step3_X_train_scaled")
X_test_scaled = load_step("step3_X_test_scaled")


# Make sure y is 1D (you already did this before, but it's safe & cheap)
y_train_arr = np.ravel(y_train)
y_test_arr = np.ravel(y_test)

# Define the ANN (MLPRegressor)
ann_reg = MLPRegressor(
    hidden_layer_sizes=(64, 32),   # 2 hidden layers: 64 and 32 neurons
    activation="relu",
    solver="adam",
    alpha=1e-3,                    # L2 regularization
    learning_rate="adaptive",
    max_iter=1000,
    early_stopping=True,           # uses 10% of training data as validation
    validation_fraction=0.1,
    n_iter_no_change=10,
    random_state=42
)

# Fit on the *scaled* features
ann_reg.fit(X_train_scaled, y_train_arr)

# Predict on test set
y_pred_ann = ann_reg.predict(X_test_scaled)

# Evaluate
mse_ann = mean_squared_error(y_test_arr, y_pred_ann)
rmse_ann = np.sqrt(mse_ann)
r2_ann = r2_score(y_test_arr, y_pred_ann)

print("Artificial Neural Network (MLPRegressor)")
print(f"MSE :  {mse_ann:.4f}")
print(f"RMSE:  {rmse_ann:.4f}")
print(f"R^2 :  {r2_ann:.44f}")

# Optional: Predicted vs Actual plot
plt.figure(figsize=(8, 6))
plt.scatter(y_test_arr, y_pred_ann, alpha=0.6, edgecolors="k", linewidth=0.5)
min_val = min(y_test_arr.min(), y_pred_ann.min())
max_val = max(y_test_arr.max(), y_pred_ann.max())
plt.plot([min_val, max_val], [min_val, max_val], "r--", lw=2, label="Perfect Prediction")
plt.xlabel("True Popularity", fontsize=12)
plt.ylabel("Predicted Popularity (ANN)", fontsize=12)
plt.title(f"ANN Regression\nGlobal R² = {r2_ann:.3f}", fontsize=14)
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Artificial Neural Network (MLPRegressor)
# MSE :  322.2637
# RMSE:  17.9517
# R^2 :  0.23394556465107996245933463796973228454589844

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import matplotlib.pyplot as plt
from utils_io import load_step, save_step

# ============================================================================
# LOAD DATA
# ============================================================================

X_train_scaled = load_step("step3_X_train_scaled")
X_test_scaled = load_step("step3_X_test_scaled")
y_train = load_step("step3_y_train")
y_test = load_step("step3_y_test")

y_train_arr = np.ravel(y_train)
y_test_arr = np.ravel(y_test)

# ============================================================================
# HYPERPARAMETER OPTIMIZATION
# ============================================================================

param_grid = {
    "hidden_layer_sizes": [
        (64,),
        (128,),
        (64, 32),
        (128, 64),
        (128, 64, 32),
    ],
    "alpha": [0.0001, 0.001, 0.01],
    "learning_rate_init": [0.001, 0.01],
    "max_iter": [500, 1000],
}

cv = KFold(n_splits=5, shuffle=True, random_state=42)

grid = GridSearchCV(
    estimator=MLPRegressor(
        activation="relu",
        solver="adam",
        early_stopping=True,
        validation_fraction=0.1,
        n_iter_no_change=10,
        random_state=42
    ),
    param_grid=param_grid,
    scoring="neg_mean_squared_error",
    cv=cv,
    n_jobs=-1,
    verbose=2
)

print("Running Grid Search for ANN...")
grid.fit(X_train_scaled, y_train_arr)

print("\n" + "="*60)
print("Best params:", grid.best_params_)
print("Best CV score (neg MSE):", grid.best_score_)
print("="*60)

# ============================================================================
# TRAIN ANN WITH BEST PARAMS
# ============================================================================

best_ann = MLPRegressor(
    **grid.best_params_,
    activation="relu",
    solver="adam",
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=10,
    random_state=42
)

best_ann.fit(X_train_scaled, y_train_arr)
y_pred_ann = best_ann.predict(X_test_scaled)

# ============================================================================
# EVALUATION
# ============================================================================

mse_ann = mean_squared_error(y_test_arr, y_pred_ann)
rmse_ann = np.sqrt(mse_ann)
r2_ann = r2_score(y_test_arr, y_pred_ann)

print("\nArtificial Neural Network (MLPRegressor)")
print(f"MSE :  {mse_ann:.4f}")
print(f"RMSE:  {rmse_ann:.4f}")
print(f"R^2 :  {r2_ann:.4f}")

# ============================================================================
# VISUALIZATION: Predicted vs Actual
# ============================================================================

plt.figure(figsize=(8, 6))
plt.scatter(y_test_arr, y_pred_ann, alpha=0.6, edgecolors="k", linewidth=0.5)
min_val = min(y_test_arr.min(), y_pred_ann.min())
max_val = max(y_test_arr.max(), y_pred_ann.max())
plt.plot([min_val, max_val], [min_val, max_val], "r--", lw=2, label="Perfect Prediction")
plt.xlabel("True Popularity", fontsize=12)
plt.ylabel("Predicted Popularity (ANN)", fontsize=12)
plt.title(f"ANN Regression\nGlobal R² = {r2_ann:.3f}", fontsize=14)
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================================
# VISUALIZATION: Training Loss Curve
# ============================================================================

plt.figure(figsize=(10, 6))
plt.plot(best_ann.loss_curve_, linewidth=2)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss (MSE)', fontsize=12)
plt.title('ANN Training Loss Over Epochs', fontsize=14)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Running Grid Search for ANN...
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=   9.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=   9.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=  10.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=  10.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=  10.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=  10.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=  11.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=  11.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   2.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   4.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   4.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   4.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   4.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   2.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   4.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   6.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   4.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=  18.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=  19.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   6.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=   7.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=  11.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=  12.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=   7.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   5.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=  12.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   4.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=  16.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=  16.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=  12.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   4.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=  16.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   6.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   5.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   5.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   4.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   4.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=  16.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   5.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   6.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=   9.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=  12.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=  13.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=   8.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=  12.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=  13.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=  13.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=  13.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=  13.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=  12.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   5.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   5.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   4.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   5.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   6.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   5.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   5.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   4.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   5.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   6.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  13.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  14.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  15.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  13.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  14.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  15.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  17.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  17.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  17.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  17.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   7.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   7.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   9.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   8.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   7.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   7.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   9.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=  10.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   8.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=  10.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  13.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  14.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  13.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  11.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  14.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  13.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  13.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  10.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=   7.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  20.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=   9.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=   9.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=  13.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=   6.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=   8.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=   9.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  20.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=   8.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=  13.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=   9.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=  11.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=  12.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=  10.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   4.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=  10.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=  11.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=  13.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   4.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=  10.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=  15.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   5.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   4.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=  12.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   4.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   5.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   3.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   5.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   4.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=  15.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   5.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=   7.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=   9.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=  10.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=   7.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   5.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=   9.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=  14.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=  10.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   4.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=  16.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=  14.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   5.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   4.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=  15.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   8.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   5.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   5.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   7.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   8.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   7.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=   7.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=   9.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=   8.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=  14.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=  12.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=  13.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   6.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=   9.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   4.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   5.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=  13.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=  15.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=  12.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   4.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   5.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   6.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   6.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   5.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   5.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   6.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  11.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  13.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  14.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  14.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  13.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  14.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   5.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   7.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   6.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  20.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   5.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   5.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  24.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   7.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  19.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   6.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   8.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  23.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   6.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   7.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  12.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  14.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  15.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  11.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  14.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  18.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  20.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  17.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  15.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=   7.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  20.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=   7.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=  10.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=   7.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=  13.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=   7.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=   9.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=  13.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=  14.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=  13.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=  13.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=   9.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=  11.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=  10.0s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=500; total time=  10.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=   9.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   5.0s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=   9.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   4.7s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=  11.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   4.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   6.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=500; total time=   4.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=  13.0s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.001, max_iter=1000; total time=  10.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   5.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   4.5s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   4.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   4.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(64,), learning_rate_init=0.01, max_iter=1000; total time=   6.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=   8.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=  12.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=   8.5s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=  14.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   4.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=  11.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=  15.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=  14.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   4.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=  15.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   5.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=500; total time=  18.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   4.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.001, max_iter=1000; total time=  17.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   7.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   4.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=500; total time=   6.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   5.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   6.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(128,), learning_rate_init=0.01, max_iter=1000; total time=   7.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=   8.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=   8.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=   9.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   4.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=  13.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   4.7s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=  14.0s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=500; total time=  14.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=  13.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=   9.7s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   5.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   4.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=500; total time=   3.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=  14.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   4.5s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   4.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.001, max_iter=1000; total time=  14.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   3.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   5.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(64, 32), learning_rate_init=0.01, max_iter=1000; total time=   5.5s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  14.5s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  15.0s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  17.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  14.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  18.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  15.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  17.0s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=500; total time=  17.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  15.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   7.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   6.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.001, max_iter=1000; total time=  19.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   7.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   6.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=500; total time=   8.0s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   5.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   8.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   7.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   8.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64), learning_rate_init=0.01, max_iter=1000; total time=   6.7s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  13.7s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  14.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  12.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  17.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  15.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=500; total time=  17.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  17.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  15.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  16.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.001, max_iter=1000; total time=  17.6s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=   7.0s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=  11.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=   5.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=   8.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=  10.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=500; total time=  10.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=   9.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=   9.0s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=   6.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(128, 64, 32), learning_rate_init=0.01, max_iter=1000; total time=   7.4s
#
# ============================================================
# Best params: {'alpha': 0.0001, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate_init': 0.001, 'max_iter': 500}
# Best CV score (neg MSE): -318.32489813650704
# ============================================================
#
# Artificial Neural Network (MLPRegressor)
# MSE :  311.6983
# RMSE:  17.6550
# R^2 :  0.2591
